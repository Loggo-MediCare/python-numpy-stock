# %% [markdown]
# <a href="https://colab.research.google.com/github/Loggo-MediCare/python-numpy-stock/blob/main/NVDA_%E4%B8%AD%E6%96%87%E4%B8%8D%E8%A1%8C_%E4%BD%86%E6%98%AF%E5%BE%88%E6%9C%89%E8%AA%AA%E6%9C%8D%E5%8A%9B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.lines import Line2D
import warnings
warnings.filterwarnings('ignore')

print("=" * 80)
print("期貨交易系統 - 錘子線可視化改進版")
print("Futures Trading System - Improved Hammer Pattern Visualization")
print("=" * 80 + "\n")

# ================================================
# 中文字體配置
# ================================================
import matplotlib.font_manager as fm
import os
import subprocess

print("配置中文字體...\n")
subprocess.run(['apt-get', 'update'], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=False)
subprocess.run(['apt-get', 'install', '-y', 'fonts-wqy-microhei'], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=False)

cache_dir = os.path.expanduser('~/.matplotlib')
for cache_file in [os.path.join(cache_dir, 'fontList.json'), os.path.join(cache_dir, 'fontList.cache')]:
    if os.path.exists(cache_file):
        try:
            os.remove(cache_file)
        except:
            pass

font_path = '/usr/share/fonts/truetype/wqy/wqy-microhei.ttc'
if os.path.exists(font_path):
    try:
        fm.fontManager.addfont(font_path)
    except:
        pass

plt.rcParams['font.sans-serif'] = ['WenQuanYi Micro Hei', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.size'] = 10

# ================================================
# 第1部分：下載數據
# ================================================
print("=" * 80)
print("第1步：下載期貨數據")
print("=" * 80 + "\n")

try:
    print("📍 下載期貨數據...")
    futures_data = yf.download("NVDA", start="2024-01-01", progress=False)

    if len(futures_data) > 0:
        start_date = str(futures_data.index[0].date())
        end_date = str(futures_data.index[-1].date())
        min_price = float(futures_data['Close'].min())
        max_price = float(futures_data['Close'].max())

        print(f"✅ 下載成功: {len(futures_data)} 個交易日")
        print(f"   日期範圍: {start_date} 到 {end_date}")
        print(f"   價格範圍: ${min_price:.2f} - ${max_price:.2f}\n")
except Exception as e:
    print(f"❌ 下載失敗: {str(e)}")
    print("使用模擬數據...\n")
    np.random.seed(42)
    dates = pd.date_range('2024-01-01', '2024-12-31', freq='B')
    prices = [100]
    for i in range(1, len(dates)):
        prices.append(prices[-1] * (1 + np.random.normal(0.0005, 0.02)))

    futures_data = pd.DataFrame({
        'Open': prices,
        'High': [p * (1 + np.abs(np.random.normal(0, 0.015))) for p in prices],
        'Low': [p * (1 - np.abs(np.random.normal(0, 0.015))) for p in prices],
        'Close': prices,
        'Volume': np.random.randint(1000000, 5000000, len(dates))
    }, index=dates)

# 標準化列名
futures_data.columns = futures_data.columns.get_level_values(0).str.lower()

# ================================================
# 第2部分：改進的錘子線檢測（多種靈敏度）
# ================================================
print("=" * 80)
print("第2步：錘子線檢測（多種靈敏度）")
print("=" * 80 + "\n")

def detect_hammer_patterns(data, strictness='normal'):
    """
    檢測多種錘子線形態

    Parameters:
    -----------
    data : DataFrame
        OHLC 數據
    strictness : str
        'strict' - 嚴格條件（符合教科書定義）
        'normal' - 正常條件（推薦）
        'loose' - 寬鬆條件（更容易觸發）
    """

    # 初始化
    hammer_strict = []
    hammer_normal = []
    hammer_loose = []
    hammer_inverted = []  # 倒錘子線（反轉信號）

    for i in range(len(data)):
        o = data['open'].iloc[i]
        h = data['high'].iloc[i]
        l = data['low'].iloc[i]
        c = data['close'].iloc[i]

        # 計算K線成分
        body = abs(c - o)
        upper_shadow = h - max(o, c)
        lower_shadow = min(o, c) - l
        total_range = h - l

        if total_range == 0:
            hammer_strict.append(0)
            hammer_normal.append(0)
            hammer_loose.append(0)
            hammer_inverted.append(0)
            continue

        # ============ 錘子線 (Hammer) ============
        # 特徵：長下影線，短上影線，小實體，通常為看漲

        # 嚴格條件（教科書）
        is_hammer_strict = (
            lower_shadow >= 2.0 * body and      # 下影線 ≥ 2倍實體
            upper_shadow <= 0.5 * body and      # 上影線 ≤ 0.5倍實體
            body <= 0.3 * total_range and       # 實體 ≤ 30% 的K線範圍
            c > o  # 收盤價 > 開盤價（看漲K線）
        )

        # 正常條件（推薦）
        is_hammer_normal = (
            lower_shadow >= 1.5 * body and      # 下影線 ≥ 1.5倍實體
            upper_shadow <= 0.75 * body and     # 上影線 ≤ 0.75倍實體
            body <= 0.4 * total_range           # 實體 ≤ 40% 的K線範圍
        )

        # 寬鬆條件（容易觸發）
        is_hammer_loose = (
            lower_shadow >= 1.2 * body and      # 下影線 ≥ 1.2倍實體
            upper_shadow <= 1.0 * body and      # 上影線 ≤ 1.0倍實體
            body <= 0.5 * total_range           # 實體 ≤ 50% 的K線範圍
        )

        # ============ 倒錘子線 (Inverted Hammer) ============
        # 特徵：長上影線，短下影線，小實體，通常為看跌（需要後續確認）

        is_inverted_hammer = (
            upper_shadow >= 1.5 * body and      # 上影線 ≥ 1.5倍實體
            lower_shadow <= 0.75 * body and     # 下影線 ≤ 0.75倍實體
            body <= 0.4 * total_range
        )

        hammer_strict.append(1 if is_hammer_strict else 0)
        hammer_normal.append(1 if is_hammer_normal else 0)
        hammer_loose.append(1 if is_hammer_loose else 0)
        hammer_inverted.append(1 if is_inverted_hammer else 0)

    # 根據指定的靈敏度返回結果
    if strictness == 'strict':
        return hammer_strict
    elif strictness == 'normal':
        return hammer_normal
    elif strictness == 'loose':
        return hammer_loose
    else:
        return hammer_normal

    return {
        'strict': hammer_strict,
        'normal': hammer_normal,
        'loose': hammer_loose,
        'inverted': hammer_inverted
    }

# 檢測三種靈敏度的錘子線
print("🔍 檢測錘子線形態...")

futures_data['Hammer_Strict'] = detect_hammer_patterns(futures_data, 'strict')
futures_data['Hammer_Normal'] = detect_hammer_patterns(futures_data, 'normal')
futures_data['Hammer_Loose'] = detect_hammer_patterns(futures_data, 'loose')

# 檢測倒錘子線
def detect_all_hammers(data):
    """同時檢測所有錘子線類型"""
    result = {
        'strict': [],
        'normal': [],
        'loose': [],
        'inverted': []
    }

    for i in range(len(data)):
        o, h, l, c = data['open'].iloc[i], data['high'].iloc[i], data['low'].iloc[i], data['close'].iloc[i]
        body = abs(c - o)
        upper = h - max(o, c)
        lower = min(o, c) - l
        total = h - l

        if total == 0:
            for key in result:
                result[key].append(0)
            continue

        # Strict Hammer
        result['strict'].append(1 if (lower >= 2.0*body and upper <= 0.5*body and body <= 0.3*total and c > o) else 0)
        # Normal Hammer
        result['normal'].append(1 if (lower >= 1.5*body and upper <= 0.75*body and body <= 0.4*total) else 0)
        # Loose Hammer
        result['loose'].append(1 if (lower >= 1.2*body and upper <= 1.0*body and body <= 0.5*total) else 0)
        # Inverted Hammer
        result['inverted'].append(1 if (upper >= 1.5*body and lower <= 0.75*body and body <= 0.4*total) else 0)

    return result

all_hammers = detect_all_hammers(futures_data)
futures_data['Hammer_Strict'] = all_hammers['strict']
futures_data['Hammer_Normal'] = all_hammers['normal']
futures_data['Hammer_Loose'] = all_hammers['loose']
futures_data['Hammer_Inverted'] = all_hammers['inverted']

# 統計
strict_count = futures_data['Hammer_Strict'].sum()
normal_count = futures_data['Hammer_Normal'].sum()
loose_count = futures_data['Hammer_Loose'].sum()
inverted_count = futures_data['Hammer_Inverted'].sum()

print(f"\n✅ 錘子線檢測結果:")
print(f"   • 嚴格標準: {strict_count} 個")
print(f"   • 正常標準: {normal_count} 個 ← 推薦使用")
print(f"   • 寬鬆標準: {loose_count} 個")
print(f"   • 倒錘子線: {inverted_count} 個")
print(f"\n   總計: {strict_count + normal_count + loose_count + inverted_count} 個形態\n")

# ================================================
# 第3部分：計算技術指標
# ================================================
print("=" * 80)
print("第3步：計算技術指標")
print("=" * 80 + "\n")

print("📈 計算指標...")

# RSI
def calculate_rsi(data, window=14):
    delta = data.diff()
    gain = delta.where(delta > 0, 0).rolling(window=window).mean()
    loss = -delta.where(delta < 0, 0).rolling(window=window).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

futures_data['RSI'] = calculate_rsi(futures_data['close'])

# MACD
futures_data['EMA_12'] = futures_data['close'].ewm(span=12, adjust=False).mean()
futures_data['EMA_26'] = futures_data['close'].ewm(span=26, adjust=False).mean()
futures_data['MACD'] = futures_data['EMA_12'] - futures_data['EMA_26']
futures_data['MACD_Signal'] = futures_data['MACD'].ewm(span=9, adjust=False).mean()
futures_data['MACD_Histogram'] = futures_data['MACD'] - futures_data['MACD_Signal']

# 布林帶
futures_data['BB_Middle'] = futures_data['close'].rolling(window=20).mean()
bb_std = futures_data['close'].rolling(window=20).std()
futures_data['BB_Upper'] = futures_data['BB_Middle'] + (bb_std * 2)
futures_data['BB_Lower'] = futures_data['BB_Middle'] - (bb_std * 2)

# 移動平均線
futures_data['MA_20'] = futures_data['close'].rolling(window=20).mean()
futures_data['MA_50'] = futures_data['close'].rolling(window=50).mean()

print("✅ 所有指標計算完成\n")

# ================================================
# 第4部分：K線圖表可視化（直接繪製K線 + 錘子線標記）
# ================================================
print("=" * 80)
print("第4步：K線圖表可視化（含錘子線直接繪製）")
print("=" * 80 + "\n")

def plot_candlesticks_with_hammer(data, start_idx=0, end_idx=None, title=""):
    """
    繪製K線圖表 + 錘子線標記

    Parameters:
    -----------
    data : DataFrame
        OHLC 數據
    start_idx, end_idx : int
        起始和結束索引
    title : str
        圖表標題
    """

    if end_idx is None:
        end_idx = len(data)

    plot_data = data.iloc[start_idx:end_idx]

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 10),
                                    gridspec_kw={'height_ratios': [3, 1]})

    # ============ 子圖1：K線 + 錘子線 ============
    width = 0.6
    width2 = 0.05

    for i, (idx, row) in enumerate(plot_data.iterrows()):
        o, h, l, c = row['open'], row['high'], row['low'], row['close']

        # 決定顏色（紅色上升，綠色下降）
        if c >= o:
            color = 'red'
            body_color = 'red'
        else:
            color = 'green'
            body_color = 'green'

        # 繪製影線 (Wick)
        ax1.plot([i, i], [l, h], color=color, linewidth=1)

        # 繪製實體 (Body)
        body_height = abs(c - o)
        body_bottom = min(o, c)
        rect = Rectangle((i - width/2, body_bottom), width, body_height,
                        facecolor=body_color, edgecolor=color, linewidth=1.5)
        ax1.add_patch(rect)

        # ============ 錘子線標記 ============
        # 嚴格標準 - 金色三角形
        if row['Hammer_Strict'] == 1:
            ax1.scatter(i, h + (h-l)*0.05, marker='^', s=200, color='gold',
                       edgecolors='orange', linewidth=2, zorder=10, label='嚴格錘子線' if i == 0 else '')
            # 在下方標記
            ax1.text(i, l - (h-l)*0.05, '🔨', ha='center', fontsize=12)

        # 正常標準 - 綠色三角形
        elif row['Hammer_Normal'] == 1:
            ax1.scatter(i, h + (h-l)*0.03, marker='^', s=150, color='lime',
                       edgecolors='darkgreen', linewidth=1.5, zorder=9, label='正常錘子線' if i == 0 else '')

        # 寬鬆標準 - 淡綠色三角形
        elif row['Hammer_Loose'] == 1:
            ax1.scatter(i, h + (h-l)*0.02, marker='^', s=100, color='lightgreen',
                       edgecolors='green', linewidth=1, zorder=8, label='寬鬆錘子線' if i == 0 else '')

        # 倒錘子線 - 紫色三角形（向下）
        if row['Hammer_Inverted'] == 1:
            ax1.scatter(i, l - (h-l)*0.05, marker='v', s=150, color='purple',
                       edgecolors='darkviolet', linewidth=1.5, zorder=9, label='倒錘子線' if i == 0 else '')

    # 繪製移動平均線
    ax1.plot(range(len(plot_data)), plot_data['MA_20'], label='MA20', color='blue', linewidth=1, alpha=0.7)
    ax1.plot(range(len(plot_data)), plot_data['MA_50'], label='MA50', color='orange', linewidth=1, alpha=0.7)

    # 繪製布林帶
    ax1.plot(range(len(plot_data)), plot_data['BB_Upper'], label='BB Upper', color='red', linestyle='--', linewidth=1, alpha=0.5)
    ax1.plot(range(len(plot_data)), plot_data['BB_Lower'], label='BB Lower', color='green', linestyle='--', linewidth=1, alpha=0.5)
    ax1.fill_between(range(len(plot_data)), plot_data['BB_Upper'], plot_data['BB_Lower'], alpha=0.1, color='gray')

    ax1.set_xlim(-1, len(plot_data))
    ax1.set_title(f'{title}\nK線圖表 - 紅色(上升) / 綠色(下降) - 🔨 表示錘子線', fontweight='bold', fontsize=12)
    ax1.set_ylabel('Price')
    ax1.legend(loc='upper left', fontsize=9)
    ax1.grid(True, alpha=0.3)

    # 設定 X 軸標籤
    tick_positions = range(0, len(plot_data), max(1, len(plot_data)//10))
    tick_labels = [plot_data.index[i].strftime('%Y-%m-%d') for i in tick_positions]
    ax1.set_xticks(tick_positions)
    ax1.set_xticklabels(tick_labels, rotation=45)

    # ============ 子圖2：RSI ============
    ax2.plot(range(len(plot_data)), plot_data['RSI'], label='RSI(14)', color='purple', linewidth=1.5)
    ax2.axhline(y=70, color='red', linestyle='--', alpha=0.5, label='Overbought (70)')
    ax2.axhline(y=30, color='green', linestyle='--', alpha=0.5, label='Oversold (30)')
    ax2.fill_between(range(len(plot_data)), 30, 70, alpha=0.1, color='gray')
    ax2.set_ylim([0, 100])
    ax2.set_title('RSI 指標', fontweight='bold')
    ax2.set_ylabel('RSI')
    ax2.legend(loc='upper left', fontsize=9)
    ax2.grid(True, alpha=0.3)
    ax2.set_xticklabels(tick_labels, rotation=45)

    plt.tight_layout()
    return fig

# 繪製全部數據
print("📊 繪製K線圖表（包含全部數據）...\n")
fig1 = plot_candlesticks_with_hammer(futures_data, title="期貨交易系統 - K線分析")
plt.savefig('/tmp/candlestick_hammer_full.png', dpi=300, bbox_inches='tight')
plt.show()

# 如果有錘子線，繪製局部放大圖表
hammer_indices = futures_data[futures_data['Hammer_Normal'] == 1].index
if len(hammer_indices) > 0:
    print(f"✅ 找到 {len(hammer_indices)} 個錘子線，繪製局部放大圖表...\n")

    # 繪製包含錘子線前後20天的圖表
    first_hammer_idx = futures_data.index.get_loc(hammer_indices[0])
    start_idx = max(0, first_hammer_idx - 20)
    end_idx = min(len(futures_data), first_hammer_idx + 30)

    fig2 = plot_candlesticks_with_hammer(
        futures_data,
        start_idx=start_idx,
        end_idx=end_idx,
        title="錘子線局部放大圖表"
    )
    plt.savefig('/tmp/candlestick_hammer_zoom.png', dpi=300, bbox_inches='tight')
    plt.show()

# ================================================
# 第5部分：錘子線詳細分析
# ================================================
print("=" * 80)
print("第5步：錘子線詳細分析")
print("=" * 80 + "\n")

def analyze_hammer_details(data):
    """詳細分析錘子線形態"""

    print("🔨 錘子線詳細統計:\n")

    # 統計各類型錘子線
    for hammer_type in ['Hammer_Strict', 'Hammer_Normal', 'Hammer_Loose', 'Hammer_Inverted']:
        hammer_data = data[data[hammer_type] == 1]

        if len(hammer_data) == 0:
            continue

        type_name = {
            'Hammer_Strict': '嚴格標準錘子線',
            'Hammer_Normal': '正常標準錘子線',
            'Hammer_Loose': '寬鬆標準錘子線',
            'Hammer_Inverted': '倒錘子線'
        }[hammer_type]

        print(f"{'='*70}")
        print(f"📊 {type_name} - 共 {len(hammer_data)} 個")
        print(f"{'='*70}")

        for i, (idx, row) in enumerate(hammer_data.head(10).iterrows()):
            date_str = idx.strftime('%Y-%m-%d')
            o, h, l, c = row['open'], row['high'], row['low'], row['close']

            body = abs(c - o)
            upper_shadow = h - max(o, c)
            lower_shadow = min(o, c) - l
            total_range = h - l

            print(f"\n{i+1}. 日期: {date_str}")
            print(f"   OHLC: O={o:.2f}, H={h:.2f}, L={l:.2f}, C={c:.2f}")
            print(f"   K線結構:")
            print(f"     • 實體長度: {body:.2f}")
            print(f"     • 上影線: {upper_shadow:.2f}")
            print(f"     • 下影線: {lower_shadow:.2f}")
            print(f"     • 下影線/實體比: {lower_shadow/body:.2f}x (越大越好)")
            print(f"   技術指標:")
            print(f"     • RSI: {row['RSI']:.2f}")
            print(f"     • MACD: {row['MACD']:.4f}")

            # 未來20天表現
            future_idx_20d = min(data.index.get_loc(idx) + 20, len(data) - 1)
            future_price = data['close'].iloc[future_idx_20d]
            future_return = (future_price - c) / c * 100

            if future_return > 0:
                print(f"     • 20天後: ↑ +{future_return:.2f}%")
            else:
                print(f"     • 20天後: ↓ {future_return:.2f}%")

        print()

analyze_hammer_details(futures_data)

# ================================================
# 第6部分：總結
# ================================================
print("=" * 80)
print("✅ 分析完成")
print("=" * 80 + "\n")

print("📌 錘子線檢測總結:")
print(f"   • 嚴格標準: {futures_data['Hammer_Strict'].sum()} 個 (最可靠)")
print(f"   • 正常標準: {futures_data['Hammer_Normal'].sum()} 個 (推薦使用)")
print(f"   • 寬鬆標準: {futures_data['Hammer_Loose'].sum()} 個")
print(f"   • 倒錘子線: {futures_data['Hammer_Inverted'].sum()} 個")

print("\n🎯 改進點說明:")
print("   ✓ 使用直接K線圖表繪製（紅綠K線）")
print("   ✓ 在K線上方顯示錘子線標記（🔨）")
print("   ✓ 支援多種檢測靈敏度")
print("   ✓ 包含倒錘子線檢測")
print("   ✓ 顯示錘子線後續20天表現")

print("\n💡 如何解讀圖表:")
print("   • 紅色K線: 收盤價 > 開盤價（看漲）")
print("   • 綠色K線: 收盤價 < 開盤價（看跌）")
print("   • 🔨 符號: 檢測到錘子線形態")
print("   • 影線長: 觸及的最高/最低價格")
print("   • 實體小: K線的實際開盤-收盤價差")

print("\n📈 使用建議:")
print("   1. 優先使用「正常標準」的錘子線")
print("   2. 在下跌趨勢末端出現時效果最佳")
print("   3. 配合RSI、MACD等指標確認")
print("   4. 注意成交量的配合")

print("\n✅ 圖表已保存:")
print("   • /tmp/candlestick_hammer_full.png")
if len(hammer_indices) > 0:
    print("   • /tmp/candlestick_hammer_zoom.png")

print("\n" + "=" * 80)
# Out:
# ================================================================================
# 期貨交易系統 - 錘子線可視化改進版
# Futures Trading System - Improved Hammer Pattern Visualization
# ================================================================================
#
# 配置中文字體...
#
# ================================================================================
# 第1步：下載期貨數據
# ================================================================================
#
# 📍 下載期貨數據...
# ✅ 下載成功: 476 個交易日
#    日期範圍: 2024-01-02 到 2025-11-21
#    價格範圍: $47.55 - $207.04
#
# ================================================================================
# 第2步：錘子線檢測（多種靈敏度）
# ================================================================================
#
# 🔍 檢測錘子線形態...
#
# ✅ 錘子線檢測結果:
#    • 嚴格標準: 6 個
#    • 正常標準: 28 個 ← 推薦使用
#    • 寬鬆標準: 52 個
#    • 倒錘子線: 18 個
#
#    總計: 104 個形態
#
# ================================================================================
# 第3步：計算技術指標
# ================================================================================
#
# 📈 計算指標...
# ✅ 所有指標計算完成
#
# ================================================================================
# 第4步：K線圖表可視化（含錘子線直接繪製）
# ================================================================================
#
# 📊 繪製K線圖表（包含全部數據）...
# ✅ 找到 28 個錘子線，繪製局部放大圖表...
# ================================================================================
# 第5步：錘子線詳細分析
# ================================================================================
#
# 🔨 錘子線詳細統計:
#
# ======================================================================
# 📊 嚴格標準錘子線 - 共 6 個
# ======================================================================
#
# 1. 日期: 2024-01-23
#    OHLC: O=59.54, H=59.88, L=58.56, C=59.84
#    K線結構:
#      • 實體長度: 0.30
#      • 上影線: 0.04
#      • 下影線: 0.98
#      • 下影線/實體比: 3.25x (越大越好)
#    技術指標:
#      • RSI: 92.46
#      • MACD: 2.8633
#      • 20天後: ↑ +12.69%
#
# 2. 日期: 2024-03-05
#    OHLC: O=85.23, H=86.06, L=83.38, C=85.92
#    K線結構:
#      • 實體長度: 0.69
#      • 上影線: 0.13
#      • 下影線: 1.85
#      • 下影線/實體比: 2.67x (越大越好)
#    技術指標:
#      • RSI: 73.41
#      • MACD: 5.6624
#      • 20天後: ↑ +3.49%
#
# 3. 日期: 2024-03-20
#    OHLC: O=89.76, H=90.37, L=88.18, C=90.33
#    K線結構:
#      • 實體長度: 0.57
#      • 上影線: 0.04
#      • 下影線: 1.57
#      • 下影線/實體比: 2.74x (越大越好)
#    技術指標:
#      • RSI: 66.96
#      • MACD: 5.2054
#      • 20天後: ↓ -6.31%
#
# 4. 日期: 2024-06-04
#    OHLC: O=115.66, H=116.55, L=113.99, C=116.38
#    K線結構:
#      • 實體長度: 0.72
#      • 上影線: 0.16
#      • 下影線: 1.67
#      • 下影線/實體比: 2.32x (越大越好)
#    技術指標:
#      • RSI: 80.86
#      • MACD: 7.0966
#      • 20天後: ↑ +10.18%
#
# 5. 日期: 2025-01-30
#    OHLC: O=123.07, H=124.97, L=118.07, C=124.62
#    K線結構:
#      • 實體長度: 1.55
#      • 上影線: 0.35
#      • 下影線: 5.00
#      • 下影線/實體比: 3.23x (越大越好)
#    技術指標:
#      • RSI: 39.66
#      • MACD: -2.6867
#      • 20天後: ↑ +0.22%
#
# 6. 日期: 2025-03-21
#    OHLC: O=116.93, H=117.98, L=115.41, C=117.69
#    K線結構:
#      • 實體長度: 0.76
#      • 上影線: 0.29
#      • 下影線: 1.52
#      • 下影線/實體比: 2.00x (越大越好)
#    技術指標:
#      • RSI: 54.25
#      • MACD: -3.1108
#      • 20天後: ↓ -17.66%
#
# ======================================================================
# 📊 正常標準錘子線 - 共 28 個
# ======================================================================
#
# 1. 日期: 2024-01-17
#    OHLC: O=56.32, H=56.44, L=54.71, C=56.02
#    K線結構:
#      • 實體長度: 0.29
#      • 上影線: 0.12
#      • 下影線: 1.31
#      • 下影線/實體比: 4.47x (越大越好)
#    技術指標:
#      • RSI: nan
#      • MACD: 1.9459
#      • 20天後: ↑ +31.84%
#
# 2. 日期: 2024-01-23
#    OHLC: O=59.54, H=59.88, L=58.56, C=59.84
#    K線結構:
#      • 實體長度: 0.30
#      • 上影線: 0.04
#      • 下影線: 0.98
#      • 下影線/實體比: 3.25x (越大越好)
#    技術指標:
#      • RSI: 92.46
#      • MACD: 2.8633
#      • 20天後: ↑ +12.69%
#
# 3. 日期: 2024-02-14
#    OHLC: O=73.17, H=74.20, L=71.90, C=73.86
#    K線結構:
#      • 實體長度: 0.70
#      • 上影線: 0.34
#      • 下影線: 1.26
#      • 下影線/實體比: 1.81x (越大越好)
#    技術指標:
#      • RSI: 81.78
#      • MACD: 5.0068
#      • 20天後: ↑ +19.01%
#
# 4. 日期: 2024-02-27
#    OHLC: O=79.34, H=79.44, L=77.12, C=78.66
#    K線結構:
#      • 實體長度: 0.68
#      • 上影線: 0.10
#      • 下影線: 1.54
#      • 下影線/實體比: 2.26x (越大越好)
#    技術指標:
#      • RSI: 70.73
#      • MACD: 4.9527
#      • 20天後: ↑ +17.62%
#
# 5. 日期: 2024-03-05
#    OHLC: O=85.23, H=86.06, L=83.38, C=85.92
#    K線結構:
#      • 實體長度: 0.69
#      • 上影線: 0.13
#      • 下影線: 1.85
#      • 下影線/實體比: 2.67x (越大越好)
#    技術指標:
#      • RSI: 73.41
#      • MACD: 5.6624
#      • 20天後: ↑ +3.49%
#
# 6. 日期: 2024-03-20
#    OHLC: O=89.76, H=90.37, L=88.18, C=90.33
#    K線結構:
#      • 實體長度: 0.57
#      • 上影線: 0.04
#      • 下影線: 1.57
#      • 下影線/實體比: 2.74x (越大越好)
#    技術指標:
#      • RSI: 66.96
#      • MACD: 5.2054
#      • 20天後: ↓ -6.31%
#
# 7. 日期: 2024-06-04
#    OHLC: O=115.66, H=116.55, L=113.99, C=116.38
#    K線結構:
#      • 實體長度: 0.72
#      • 上影線: 0.16
#      • 下影線: 1.67
#      • 下影線/實體比: 2.32x (越大越好)
#    技術指標:
#      • RSI: 80.86
#      • MACD: 7.0966
#      • 20天後: ↑ +10.18%
#
# 8. 日期: 2024-06-07
#    OHLC: O=119.72, H=121.64, L=117.97, C=120.83
#    K線結構:
#      • 實體長度: 1.12
#      • 上影線: 0.80
#      • 下影線: 1.75
#      • 下影線/實體比: 1.56x (越大越好)
#    技術指標:
#      • RSI: 83.21
#      • MACD: 8.2878
#      • 20天後: ↑ +8.69%
#
# 9. 日期: 2024-07-01
#    OHLC: O=123.42, H=124.79, L=118.79, C=124.25
#    K線結構:
#      • 實體長度: 0.83
#      • 上影線: 0.54
#      • 下影線: 4.64
#      • 下影線/實體比: 5.59x (越大越好)
#    技術指標:
#      • RSI: 52.70
#      • MACD: 5.2702
#      • 20天後: ↓ -16.55%
#
# 10. 日期: 2024-07-10
#    OHLC: O=133.98, H=135.05, L=132.37, C=134.86
#    K線結構:
#      • 實體長度: 0.88
#      • 上影線: 0.19
#      • 下影線: 1.61
#      • 下影線/實體比: 1.83x (越大越好)
#    技術指標:
#      • RSI: 49.30
#      • MACD: 4.8443
#      • 20天後: ↓ -26.68%
#
# ======================================================================
# 📊 寬鬆標準錘子線 - 共 52 個
# ======================================================================
#
# 1. 日期: 2024-01-17
#    OHLC: O=56.32, H=56.44, L=54.71, C=56.02
#    K線結構:
#      • 實體長度: 0.29
#      • 上影線: 0.12
#      • 下影線: 1.31
#      • 下影線/實體比: 4.47x (越大越好)
#    技術指標:
#      • RSI: nan
#      • MACD: 1.9459
#      • 20天後: ↑ +31.84%
#
# 2. 日期: 2024-01-22
#    OHLC: O=60.02, H=60.30, L=59.04, C=59.62
#    K線結構:
#      • 實體長度: 0.39
#      • 上影線: 0.28
#      • 下影線: 0.58
#      • 下影線/實體比: 1.48x (越大越好)
#    技術指標:
#      • RSI: 92.33
#      • MACD: 2.6930
#      • 20天後: ↑ +16.42%
#
# 3. 日期: 2024-01-23
#    OHLC: O=59.54, H=59.88, L=58.56, C=59.84
#    K線結構:
#      • 實體長度: 0.30
#      • 上影線: 0.04
#      • 下影線: 0.98
#      • 下影線/實體比: 3.25x (越大越好)
#    技術指標:
#      • RSI: 92.46
#      • MACD: 2.8633
#      • 20天後: ↑ +12.69%
#
# 4. 日期: 2024-02-06
#    OHLC: O=69.60, H=69.72, L=66.27, C=68.19
#    K線結構:
#      • 實體長度: 1.41
#      • 上影線: 0.12
#      • 下影線: 1.92
#      • 下影線/實體比: 1.37x (越大越好)
#    技術指標:
#      • RSI: 83.70
#      • MACD: 4.1695
#      • 20天後: ↑ +30.02%
#
# 5. 日期: 2024-02-14
#    OHLC: O=73.17, H=74.20, L=71.90, C=73.86
#    K線結構:
#      • 實體長度: 0.70
#      • 上影線: 0.34
#      • 下影線: 1.26
#      • 下影線/實體比: 1.81x (越大越好)
#    技術指標:
#      • RSI: 81.78
#      • MACD: 5.0068
#      • 20天後: ↑ +19.01%
#
# 6. 日期: 2024-02-27
#    OHLC: O=79.34, H=79.44, L=77.12, C=78.66
#    K線結構:
#      • 實體長度: 0.68
#      • 上影線: 0.10
#      • 下影線: 1.54
#      • 下影線/實體比: 2.26x (越大越好)
#    技術指標:
#      • RSI: 70.73
#      • MACD: 4.9527
#      • 20天後: ↑ +17.62%
#
# 7. 日期: 2024-03-05
#    OHLC: O=85.23, H=86.06, L=83.38, C=85.92
#    K線結構:
#      • 實體長度: 0.69
#      • 上影線: 0.13
#      • 下影線: 1.85
#      • 下影線/實體比: 2.67x (越大越好)
#    技術指標:
#      • RSI: 73.41
#      • MACD: 5.6624
#      • 20天後: ↑ +3.49%
#
# 8. 日期: 2024-03-20
#    OHLC: O=89.76, H=90.37, L=88.18, C=90.33
#    K線結構:
#      • 實體長度: 0.57
#      • 上影線: 0.04
#      • 下影線: 1.57
#      • 下影線/實體比: 2.74x (越大越好)
#    技術指標:
#      • RSI: 66.96
#      • MACD: 5.2054
#      • 20天後: ↓ -6.31%
#
# 9. 日期: 2024-04-22
#    OHLC: O=78.07, H=80.04, L=76.37, C=79.48
#    K線結構:
#      • 實體長度: 1.41
#      • 上影線: 0.55
#      • 下影線: 1.70
#      • 下影線/實體比: 1.21x (越大越好)
#    技術指標:
#      • RSI: 35.97
#      • MACD: -1.0042
#      • 20天後: ↑ +19.19%
#
# 10. 日期: 2024-05-29
#    OHLC: O=113.00, H=115.44, L=110.85, C=114.77
#    K線結構:
#      • 實體長度: 1.77
#      • 上影線: 0.67
#      • 下影線: 2.15
#      • 下影線/實體比: 1.21x (越大越好)
#    技術指標:
#      • RSI: 87.08
#      • MACD: 5.9046
#      • 20天後: ↑ +7.99%
#
# ======================================================================
# 📊 倒錘子線 - 共 18 個
# ======================================================================
#
# 1. 日期: 2024-02-08
#    OHLC: O=70.04, H=70.76, L=69.42, C=69.61
#    K線結構:
#      • 實體長度: 0.43
#      • 上影線: 0.72
#      • 下影線: 0.19
#      • 下影線/實體比: 0.43x (越大越好)
#    技術指標:
#      • RSI: 79.94
#      • MACD: 4.5010
#      • 20天後: ↑ +25.69%
#
# 2. 日期: 2024-03-04
#    OHLC: O=84.09, H=87.65, L=83.68, C=85.19
#    K線結構:
#      • 實體長度: 1.11
#      • 上影線: 2.46
#      • 下影線: 0.41
#      • 下影線/實體比: 0.37x (越大越好)
#    技術指標:
#      • RSI: 72.44
#      • MACD: 5.4053
#      • 20天後: ↑ +4.95%
#
# 3. 日期: 2024-03-15
#    OHLC: O=86.89, H=89.51, L=86.22, C=87.80
#    K線結構:
#      • 實體長度: 0.91
#      • 上影線: 1.71
#      • 下影線: 0.67
#      • 下影線/實體比: 0.74x (越大越好)
#    技術指標:
#      • RSI: 63.04
#      • MACD: 5.7986
#      • 20天後: ↓ -2.09%
#
# 4. 日期: 2024-03-25
#    OHLC: O=93.90, H=96.72, L=93.47, C=94.96
#    K線結構:
#      • 實體長度: 1.06
#      • 上影線: 1.76
#      • 下影線: 0.43
#      • 下影線/實體比: 0.41x (越大越好)
#    技術指標:
#      • RSI: 64.59
#      • MACD: 5.3110
#      • 20天後: ↓ -13.24%
#
# 5. 日期: 2024-04-03
#    OHLC: O=88.44, H=90.33, L=88.36, C=88.92
#    K線結構:
#      • 實體長度: 0.48
#      • 上影線: 1.41
#      • 下影線: 0.08
#      • 下影線/實體比: 0.18x (越大越好)
#    技術指標:
#      • RSI: 44.16
#      • MACD: 3.2974
#      • 20天後: ↓ -6.66%
#
# 6. 日期: 2024-04-30
#    OHLC: O=87.20, H=88.78, L=86.26, C=86.36
#    K線結構:
#      • 實體長度: 0.84
#      • 上影線: 1.58
#      • 下影線: 0.10
#      • 下影線/實體比: 0.12x (越大越好)
#    技術指標:
#      • RSI: 49.21
#      • MACD: -0.3231
#      • 20天後: ↑ +32.90%
#
# 7. 日期: 2024-05-16
#    OHLC: O=94.87, H=95.78, L=94.06, C=94.32
#    K線結構:
#      • 實體長度: 0.55
#      • 上影線: 0.91
#      • 下影線: 0.26
#      • 下影線/實體比: 0.46x (越大越好)
#    技術指標:
#      • RSI: 64.16
#      • MACD: 1.9929
#      • 20天後: ↑ +39.78%
#
# 8. 日期: 2024-07-08
#    OHLC: O=127.44, H=130.72, L=126.99, C=128.15
#    K線結構:
#      • 實體長度: 0.71
#      • 上影線: 2.57
#      • 下影線: 0.45
#      • 下影線/實體比: 0.63x (越大越好)
#    技術指標:
#      • RSI: 46.08
#      • MACD: 4.3545
#      • 20天後: ↓ -21.65%
#
# 9. 日期: 2024-09-19
#    OHLC: O=117.32, H=119.63, L=117.22, C=117.84
#    K線結構:
#      • 實體長度: 0.52
#      • 上影線: 1.79
#      • 下影線: 0.10
#      • 下影線/實體比: 0.19x (越大越好)
#    技術指標:
#      • RSI: 50.31
#      • MACD: -0.5022
#      • 20天後: ↑ +16.17%
#
# 10. 日期: 2024-10-25
#    OHLC: O=140.89, H=144.09, L=140.76, C=141.50
#    K線結構:
#      • 實體長度: 0.61
#      • 上影線: 2.59
#      • 下影線: 0.13
#      • 下影線/實體比: 0.21x (越大越好)
#    技術指標:
#      • RSI: 69.43
#      • MACD: 5.6776
#      • 20天後: ↑ +0.29%
#
# ================================================================================
# ✅ 分析完成
# ================================================================================
#
# 📌 錘子線檢測總結:
#    • 嚴格標準: 6 個 (最可靠)
#    • 正常標準: 28 個 (推薦使用)
#    • 寬鬆標準: 52 個
#    • 倒錘子線: 18 個
#
# 🎯 改進點說明:
#    ✓ 使用直接K線圖表繪製（紅綠K線）
#    ✓ 在K線上方顯示錘子線標記（🔨）
#    ✓ 支援多種檢測靈敏度
#    ✓ 包含倒錘子線檢測
#    ✓ 顯示錘子線後續20天表現
#
# 💡 如何解讀圖表:
#    • 紅色K線: 收盤價 > 開盤價（看漲）
#    • 綠色K線: 收盤價 < 開盤價（看跌）
#    • 🔨 符號: 檢測到錘子線形態
#    • 影線長: 觸及的最高/最低價格
#    • 實體小: K線的實際開盤-收盤價差
#
# 📈 使用建議:
#    1. 優先使用「正常標準」的錘子線
#    2. 在下跌趨勢末端出現時效果最佳
#    3. 配合RSI、MACD等指標確認
#    4. 注意成交量的配合
#
# ✅ 圖表已保存:
#    • /tmp/candlestick_hammer_full.png
#    • /tmp/candlestick_hammer_zoom.png
#
# ================================================================================

# %%
# !pip install yfinance arch statsmodels scipy matplotlib pmdarima
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: arch in /usr/local/lib/python3.12/dist-packages (8.0.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (0.14.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Collecting pmdarima
#   Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from arch) (25.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.5.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (75.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.1.1

# %%
# ============================================================
# Nvidia (NVDA) 股價預測：GBM + GJR-GARCH (t分布厚尾風險版)
# ============================================================
# 此模型結合了：
# 1. 幾何布朗運動 (GBM) 的價格模擬邏輯。
# 2. GJR-GARCH(t) 模型預測的每日波動率 (捕捉波動聚集和槓桿效應)。
# 3. Student-t 分佈捕捉厚尾風險。

# !pip install arch

import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.stats import t, jarque_bera
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# 【Cell 1】中文字體修復 (解決圖表中文亂碼問題)
#silvia-----------------------------------------------------------------------------------------------------------------------------------------------

# ==================== 配置中文字體 ====================
warnings.filterwarnings('ignore', category=UserWarning, module='matplotlib')

import matplotlib
import matplotlib.font_manager as fm
import os
import subprocess
import sys

print("正在安装并配置中文字体...")

subprocess.run(['apt-get', 'update'],
               stdout=subprocess.DEVNULL,
               stderr=subprocess.DEVNULL,
               check=False
)

subprocess.run(['apt-get', 'install', '-y', 'fonts-wqy-microhei'],
               stdout=subprocess.DEVNULL,
               stderr=subprocess.DEVNULL,
               check=False
)

cache_dir = os.path.expanduser('~/.matplotlib')
for cache_file in [
    os.path.join(cache_dir, 'fontList.json'),
    os.path.join(cache_dir, 'fontList.cache')
]:
    if os.path.exists(cache_file):
        try:
            os.remove(cache_file)
        except Exception as e:
            pass

font_path_wqy = '/usr/share/fonts/truetype/wqy/wqy-microhei.ttc'
if os.path.exists(font_path_wqy):
    try:
        fm.fontManager.addfont(font_path_wqy)
    except Exception as e:
        pass

font_options = [
    'WenQuanYi Micro Hei',
    'Noto Sans CJK SC',
    'SimHei',
    'DejaVu Sans'
]

selected_font = None
for font in font_options:
    if font in [f.name for f in fm.fontManager.ttflist]:
        plt.rcParams['font.sans-serif'] = [font]
        selected_font = font
        break

if not selected_font:
    plt.rcParams['font.sans-serif'] = ['DejaVu Sans']
    print("⚠️ 未能找到合适的中文字体")
else:
    print(f"✓ 已设置中文字体：{selected_font}")

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.size'] = 10

print("中文字体配置完成！\n")


#silvia---------------------------------------------------------------------------------------------------------------------

plt.rcParams['font.sans-serif'] = ['SimHei', 'Microsoft YaHei', 'Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 自動 ARIMA 模型 (用於確定趨勢/殘差)
try:
    from pmdarima import auto_arima
except ImportError:
    # 如果 pmdarima 未安裝，則使用 statsmodels 的 ARIMA(1,0,1)
    print("⚠️ pmdarima 未安裝。使用預設 ARIMA(1,0,1) 進行殘差計算。")
    from statsmodels.tsa.arima.model import ARIMA
    auto_arima = None

# ARCH 模型 (GJR-GARCH 支援)
from arch import arch_model

# ============================================================
# Step 1. 下載或載入資料
# ============================================================
# 修正為 2330.TW，並確保下載日期到今天為止
symbol = "NVDA"
end_date_obj = datetime.now() + timedelta(days=1)
end_date_str = end_date_obj.strftime("%Y-%m-%d")

try:
    data = yf.download(symbol, start="2020-01-01", end=end_date_str)
    print(f"✅ 成功從 Yahoo Finance 下載 {symbol} 歷史資料 (至 {end_date_str} 前)")
except Exception as e:
    print(f"⚠️ yfinance 無法下載: {e}")
    data = pd.DataFrame()

if data.empty:
    raise ValueError("無法取得股價資料，請檢查代碼或連線。")

data = data[['Close']].dropna()
data.rename(columns={'Close': 'Price'}, inplace=True)
# 計算對數報酬率 (用於 GBM 和 GARCH 訓練)
data['Log_Return'] = np.log(data['Price'] / data['Price'].shift(1)) * 100
returns = data['Log_Return'].dropna()

# ------------------------------------------------------------
# 確定模擬起點價格 (使用下載數據中的最新價格)
# ------------------------------------------------------------
last_price = data['Price'].iloc[-1]
last_date = data.index[-1]

print(f"📌 模型將使用 Yahoo Finance 下載到的最新價格作為模擬起點: {last_price.item():.2f} USD (日期: {last_date.strftime('%Y-%m-%d')})")
# ------------------------------------------------------------


# ============================================================
# Step 2. 自動化 ARIMA 模型 (獲取殘差)
# ============================================================
if auto_arima is not None:
    print("\n🔍 自動選擇最佳 ARIMA 模型參數中 ...")
    arima_model = auto_arima(returns, seasonal=False, stepwise=True, suppress_warnings=True, trace=False)
    order = arima_model.order
    print(f"✅ 最佳 ARIMA 模型階數: {order}")
    residuals = arima_model.resid()
else:
    print("⚠️ 使用預設 ARIMA(1,0,1) 進行殘差計算。")
    arima_model = ARIMA(returns, order=(1,0,1)).fit()
    residuals = arima_model.resid

# ============================================================
# Step 3. 殘差厚尾性檢驗
# ============================================================
jb_stat, jb_pval = jarque_bera(residuals)
skewness = residuals.skew()
kurtosis_val = residuals.kurtosis()

print("\n📊 殘差分佈檢驗：Jarque-Bera")
print(f"  JB統計量: {jb_stat:.3f}, p值: {jb_pval:.5f}")
print(f"  偏度: {skewness:.3f}, 峰度: {kurtosis_val:.3f}")
if jb_pval < 0.05:
    print("  ⚠️ 殘差非正態分布 → 存在厚尾風險 (Fat Tail Risk)，GJR-GARCHt 適用。")
else:
    print("  ✓ 殘差近似正態。")

# ============================================================
# Step 4. 建立 GJR-GARCH 模型 (t分布)
# ============================================================
print("\n📈 擬合 GJR-GARCH(1,1,1) 模型 (t分布) ...")
# vol='Garch' p=1, q=1, o=1 則為 GJR-GARCH(1,1,1)
gjr_t = arch_model(residuals, vol='Garch', p=1, q=1, o=1, dist='t')
gjr_t_result = gjr_t.fit(disp='off')

# 提取模型參數
nu = gjr_t_result.params['nu']
gamma = gjr_t_result.params.get('gamma[1]', 0)

# ============================================================
# Step 5. Monte Carlo 模擬 (GBM + GJR-GARCHt)
# ** 修正模擬：使用每日預測波動率序列 **
# ============================================================
T = 22       # 預測未來 22 個交易日
N = 10000    # 模擬次數

# GBM 參數
mu = returns.mean() / 100
# 獲取未來 T 天的每日波動率預測序列 (Sigma_t)
forecast_variance = gjr_t_result.forecast(horizon=T).variance.values[-1, :]
vol_forecast_series = np.sqrt(forecast_variance) / 100 # 每日预测的波动率 (sigma_t)

print(f"\n🎯 模型參數摘要:")
print(f"  漂移項 (μ): {mu*100:.3f}% (日平均對數報酬率)")
print(f"  GJR-GARCH 自由度 (ν): {nu:.2f}")

np.random.seed(42)
simulated_end_prices = []
all_simulated_paths = np.empty((N, T + 1))

for i in range(N):
    price_path = np.zeros(T + 1)
    price_path[0] = last_price

    for t_step in range(T):
        sigma_t = vol_forecast_series[t_step]

        # 1. 調整 Student-t 分佈的尺度，使其方差與 GARCH 預測的波動率一致
        if nu > 2:
            t_scale_t = sigma_t / np.sqrt(nu/(nu-2))
        else:
            t_scale_t = sigma_t

        # 2. 從 Student-t 分佈中取樣隨機變量
        t_random_shock = t.rvs(df=nu, size=1)[0] * t_scale_t

        # 3. GBM 價格模擬公式
        # dS/S = (mu - 0.5 * sigma^2) dt + sigma dW_t
        log_return_term = (mu - 0.5 * sigma_t**2) * 1 + t_random_shock
        price_path[t_step + 1] = price_path[t_step] * np.exp(log_return_term)

    simulated_end_prices.append(price_path[-1])
    all_simulated_paths[i, :] = price_path

simulated_end_prices = np.array(simulated_end_prices)

# ============================================================
# Step 6. 目標價與風險指標計算 (風險管理區間)
# ============================================================
conservative_price = np.percentile(simulated_end_prices, 5)
neutral_price = np.percentile(simulated_end_prices, 50)
optimistic_price = np.percentile(simulated_end_prices, 95)
cvar_95 = np.mean(simulated_end_prices[simulated_end_prices <= conservative_price])

# ============================================================
# Step 7. 視覺化結果
# ============================================================
# 1. 價格分佈直方圖
plt.figure(figsize=(12, 6))
plt.hist(simulated_end_prices, bins=50, density=True, alpha=0.6, color='skyblue')
plt.axvline(last_price.item(), color='black', linestyle='-', linewidth=2, label=f'現價: {last_price.item():.2f} USD')
plt.axvline(conservative_price, color='red', linestyle='--', label=f'保守目標 (VaR 5%): {conservative_price:.2f}')
plt.axvline(neutral_price, color='green', linestyle='-', label=f'中性目標 (Median): {neutral_price:.2f}')
plt.axvline(optimistic_price, color='blue', linestyle='--', label=f'樂觀目標 (95%): {optimistic_price:.2f}')
plt.title(f"台積電 ({symbol}) {T} 天後目標價格分佈 (GBM + GJR-GARCHt, N={N})", fontsize=14)
plt.xlabel("價格 (USD)")
plt.ylabel("機率密度")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# 2. 模擬路徑圖 (繪製部分路徑)
plt.figure(figsize=(12, 6))
time_steps = pd.date_range(start=last_date, periods=T + 1, freq='B')
plt.plot(time_steps, all_simulated_paths[::N//100].T, color='gray', alpha=0.1)
plt.plot(time_steps, np.median(all_simulated_paths, axis=0), color='green', linewidth=2, label='中性路徑 (50% 中位數)')
plt.plot(time_steps, np.percentile(all_simulated_paths, 5, axis=0), color='red', linestyle='--', label='保守路徑 (5% 分位數)')
plt.plot(time_steps, np.percentile(all_simulated_paths, 95, axis=0), color='blue', linestyle='--', label='樂觀路徑 (95% 分位數)')
plt.title(f"台積電 ({symbol}) 股價模擬路徑 (未來 {T} 天)", fontsize=14)
plt.xlabel("日期")
plt.ylabel("價格 (USD)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()


# ============================================================
# Step 8. 結果摘要與投資建議 (CFA 交易決策點)
# ============================================================
print("\n" + "="*65)
print("💡 GBM + GJR-GARCHt 模型預測結果與交易決策")
print("="*65)
print(f"當前股價: {last_price.item():.2f} USD")
print(f"預測期間: {T} 個交易日 (約一個月)")
print("-----------------------------------")
print(f"**保守目標價 (5% VaR):** {conservative_price:.2f} USD (跌幅 {(conservative_price/last_price.item()-1)*100:.2f}%)")
print(f"**中性目標價 (50% Median):** {neutral_price:.2f} USD (漲幅 {(neutral_price/last_price.item()-1)*100:.2f}%)")
print(f"**樂觀目標價 (95% Upside):** {optimistic_price:.2f} USD (漲幅 {(optimistic_price/last_price.item()-1)*100:.2f}%) ")
print("-----------------------------------")
print(f"條件風險 CVaR 95%: {cvar_95:.2f} USD (極端下跌時的平均價格)")
print(f"GJR 槓桿效應 γ: {gamma:.3f} → {'下跌時波動放大' if gamma>0.001 else '對稱波動或輕微反向'}")
print(f"厚尾程度 (峰度): {kurtosis_val:.3f}")
print("===================================")

# 新增交易決策點判斷 (基於風險與預期報酬)
mean_return_forecast = (simulated_end_prices.mean() / last_price.item() - 1) * 100

print("\n--- 交易決策與指標建議 (CFA 視角) ---")
print(f"預期未來月報酬率 (μ): {mean_return_forecast:.2f}%")

if conservative_price < last_price.item() * 0.97 and optimistic_price > last_price.item() * 1.05 and mean_return_forecast > 0.5:
    print("\n✅ 潛在買入訊號: 預期報酬率為正，且上漲空間 (95%區間) 大於下跌風險 (5%區間)。")
    print(f"   - **止損點 (Stop-Loss/VaR):** {conservative_price:.2f} USD ({last_price.item() - conservative_price:.2f} USD 絕對風險)。")
    print(f"   - **止盈點 (Take-Profit):** {optimistic_price:.2f} USD (建議分批獲利了結，避免單次賣出)。")
elif conservative_price < last_price.item() * 0.95 and mean_return_forecast < 0:
    print("\n⚠️ 警示訊號: 預期報酬率為負，下跌風險（5% VaR）相對較大。")
    print(f"   - **建議策略:** 考慮避險或減碼。{conservative_price:.2f} USD 為主要風險區域。")
else:
    print("\nℹ️ 中性/觀望訊號: 預期報酬和風險相對平衡，或無明確趨勢。")
    print("   - **建議策略:** 保持觀望，等待技術面或籌碼面指標出現明確信號。")

# 提示納入外部指標的建議
print("\n--- 進階指標整合建議 ---")
print("   - **趨勢濾網:** 建議納入 MACD 或 ADX 作為趨勢過濾指標 (參見 PDF 第 31 頁)。")
print("   - **籌碼濾網:** 建議結合外資買賣超/融資餘額，以增加交易的信心與勝率。")
print("   - **波動率應用:** 可將每日預測波動率 (Sigma_t) 用於動態調整期權 Gamma Scalping 策略。")

print("====================================")
# Out:
# Requirement already satisfied: arch in /usr/local/lib/python3.12/dist-packages (8.0.0)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from arch) (2.0.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from arch) (2.2.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.12/dist-packages (from arch) (1.16.3)
# Requirement already satisfied: statsmodels>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from arch) (0.14.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from arch) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.0->arch) (2025.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.13.0->arch) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->arch) (1.17.0)
# 正在安装并配置中文字体...
# [*********************100%***********************]  1 of 1 completed
# ✓ 已设置中文字体：WenQuanYi Micro Hei
# 中文字体配置完成！
#
# ✅ 成功從 Yahoo Finance 下載 NVDA 歷史資料 (至 2025-11-23 前)
# 📌 模型將使用 Yahoo Finance 下載到的最新價格作為模擬起點: 178.88 USD (日期: 2025-11-21)
#
# 🔍 自動選擇最佳 ARIMA 模型參數中 ...
# ✅ 最佳 ARIMA 模型階數: (2, 0, 2)
#
# 📊 殘差分佈檢驗：Jarque-Bera
#   JB統計量: 852.534, p值: 0.00000
#   偏度: 0.022, 峰度: 3.733
#   ⚠️ 殘差非正態分布 → 存在厚尾風險 (Fat Tail Risk)，GJR-GARCHt 適用。
#
# 📈 擬合 GJR-GARCH(1,1,1) 模型 (t分布) ...
#
# 🎯 模型參數摘要:
#   漂移項 (μ): 0.230% (日平均對數報酬率)
#   GJR-GARCH 自由度 (ν): 6.55
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei, Microsoft YaHei, Arial Unicode MS
# =================================================================
# 💡 GBM + GJR-GARCHt 模型預測結果與交易決策
# =================================================================
# 當前股價: 178.88 USD
# 預測期間: 22 個交易日 (約一個月)
# -----------------------------------
# **保守目標價 (5% VaR):** 144.81 USD (跌幅 -19.05%)
# **中性目標價 (50% Median):** 186.36 USD (漲幅 4.18%)
# **樂觀目標價 (95% Upside):** 239.04 USD (漲幅 33.63%)
# -----------------------------------
# 條件風險 CVaR 95%: 136.24 USD (極端下跌時的平均價格)
# GJR 槓桿效應 γ: 0.099 → 下跌時波動放大
# 厚尾程度 (峰度): 3.733
# ===================================
#
# --- 交易決策與指標建議 (CFA 視角) ---
# 預期未來月報酬率 (μ): 5.20%
#
# ✅ 潛在買入訊號: 預期報酬率為正，且上漲空間 (95%區間) 大於下跌風險 (5%區間)。
#    - **止損點 (Stop-Loss/VaR):** 144.81 USD (34.07 USD 絕對風險)。
#    - **止盈點 (Take-Profit):** 239.04 USD (建議分批獲利了結，避免單次賣出)。
#
# --- 進階指標整合建議 ---
#    - **趨勢濾網:** 建議納入 MACD 或 ADX 作為趨勢過濾指標 (參見 PDF 第 31 頁)。
#    - **籌碼濾網:** 建議結合外資買賣超/融資餘額，以增加交易的信心與勝率。
#    - **波動率應用:** 可將每日預測波動率 (Sigma_t) 用於動態調整期權 Gamma Scalping 策略。
# ====================================

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import time
import os
import matplotlib.pyplot as plt

# 定義神經網絡模型
class LetterNet(nn.Module):
    def __init__(self):
        super(LetterNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout2d(0.25)
        self.dropout2 = nn.Dropout2d(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 26)  # 26個英文字母

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        output = F.log_softmax(x, dim=1)
        return output

# 訓練函數
def train(model, device, train_loader, optimizer, epoch):
    model.train()


    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print(f'訓練進度: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)}]')
            if device.type == "cuda":
                print(f"[GPU] 使用記憶體: {torch.cuda.memory_allocated() / 1024**2:.2f} MiB")
                print(f"[GPU] 最⼤使⽤記憶體: {torch.cuda.max_memory_allocated() / 1024**2:.2f} MiB")

# 測試函數
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    print(f'測試集: 平均損失: {test_loss:.4f}, 準確率: {correct}/{len(test_loader.dataset)} ({accuracy:.1f}%)')
    return accuracy

# 轉換EMNIST數據集的標籤（1-26 → 0-25）
def emnist_target_transform(target):
    return target - 1

# 訓練模型並計時
def train_model(device_name, epochs=5):
    if device_name == "cuda" and not torch.cuda.is_available():
        print("CUDA不可用，切換到CPU訓練")
        device_name = "cpu"
    device = torch.device(device_name)
    print(f"使用{device_name}進行訓練")

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])

    train_dataset = datasets.EMNIST(
        '../data', split='letters', train=True, download=True,
        transform=transform, target_transform=emnist_target_transform
    )
    test_dataset = datasets.EMNIST(
        '../data', split='letters', train=False,
        transform=transform, target_transform=emnist_target_transform
    )

    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=1000)

    model = LetterNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()
    accuracies = []

    for epoch in range(1, epochs + 1):
        epoch_start = time.time()
        train(model, device, train_loader, optimizer, epoch)
        accuracy = test(model, device, test_loader)
        accuracies.append(accuracy)
        epoch_end = time.time()
        print(f"第{epoch}輪訓練用時: {epoch_end - epoch_start:.2f}秒")

    total_time = time.time() - start_time
    print(f"總訓練時間: {total_time:.2f}秒")

    os.makedirs('models', exist_ok=True)
    model_path = f"models/letter_model_{device_name}.pt"
    torch.save(model.state_dict(), model_path)
    print(f"模型已保存到 {model_path}")

    return total_time, accuracies

# 主函數
def main():
    epochs = 3

    cpu_time, cpu_accuracies = train_model("cpu", epochs)
    gpu_time, gpu_accuracies = train_model("cuda", epochs)

    speedup = cpu_time / gpu_time if gpu_time > 0 else float('inf')

    with open("training_comparison.txt", "w") as f:
        f.write("英文字母識別模型訓練時間比較\n")
        f.write("=" * 40 + "\n")
        f.write(f"訓練輪數: {epochs}\n\n")
        f.write("CPU訓練:\n")
        f.write(f"  - 總時間: {cpu_time:.2f}秒\n")
        f.write(f"  - 最終準確率: {cpu_accuracies[-1]:.2f}%\n\n")
        f.write("GPU訓練:\n")
        f.write(f"  - 總時間: {gpu_time:.2f}秒\n")
        f.write(f"  - 最終準確率: {gpu_accuracies[-1]:.2f}%\n\n")
        f.write(f"GPU加速比: {speedup:.2f}x\n")
        f.write("=" * 40 + "\n")
        f.write("\n每輪訓練準確率:\n")
        f.write("輪數\tCPU準確率\tGPU準確率\n")
        for i in range(epochs):
            f.write(f"{i+1}\t{cpu_accuracies[i]:.2f}%\t{gpu_accuracies[i]:.2f}%\n")

    print(f"比較結果已保存到 'training_comparison.txt'")

    plt.figure(figsize=(10, 6))
    plt.plot(range(1, epochs + 1), cpu_accuracies, marker='o', label='CPU')
    plt.plot(range(1, epochs + 1), gpu_accuracies, marker='s', label='GPU')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.title('CPU vs GPU Training Accuracy')
    plt.legend()
    plt.grid(True)
    plt.savefig('accuracy_comparison.png')
    print("準確率比較圖已保存到 'accuracy_comparison.png'")

if __name__ == '__main__':
    main()
# Out:
# 使用cpu進行訓練
# 100%|██████████| 562M/562M [00:05<00:00, 109MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:1538: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
# 訓練進度: 1 [0/124800]
# 訓練進度: 1 [6400/124800]
# 訓練進度: 1 [12800/124800]
# 訓練進度: 1 [19200/124800]
# 訓練進度: 1 [25600/124800]
# 訓練進度: 1 [32000/124800]
# 訓練進度: 1 [38400/124800]
# 訓練進度: 1 [44800/124800]
# 訓練進度: 1 [51200/124800]
# 訓練進度: 1 [57600/124800]
# 訓練進度: 1 [64000/124800]
# 訓練進度: 1 [70400/124800]
# 訓練進度: 1 [76800/124800]
# 訓練進度: 1 [83200/124800]
# 訓練進度: 1 [89600/124800]
# 訓練進度: 1 [96000/124800]
# 訓練進度: 1 [102400/124800]
# 訓練進度: 1 [108800/124800]
# 訓練進度: 1 [115200/124800]
# 訓練進度: 1 [121600/124800]
# 測試集: 平均損失: 0.2989, 準確率: 18807/20800 (90.4%)
# 第1輪訓練用時: 214.26秒
# 訓練進度: 2 [0/124800]
# 訓練進度: 2 [6400/124800]
# 訓練進度: 2 [12800/124800]
# 訓練進度: 2 [19200/124800]
# 訓練進度: 2 [25600/124800]
# 訓練進度: 2 [32000/124800]
# 訓練進度: 2 [38400/124800]
# 訓練進度: 2 [44800/124800]
# 訓練進度: 2 [51200/124800]
# 訓練進度: 2 [57600/124800]
# 訓練進度: 2 [64000/124800]
# 訓練進度: 2 [70400/124800]
# 訓練進度: 2 [76800/124800]
# 訓練進度: 2 [83200/124800]
# 訓練進度: 2 [89600/124800]
# 訓練進度: 2 [96000/124800]
# 訓練進度: 2 [102400/124800]
# 訓練進度: 2 [108800/124800]
# 訓練進度: 2 [115200/124800]
# 訓練進度: 2 [121600/124800]
# 測試集: 平均損失: 0.2540, 準確率: 19139/20800 (92.0%)
# 第2輪訓練用時: 222.91秒
# 訓練進度: 3 [0/124800]
# 訓練進度: 3 [6400/124800]
# 訓練進度: 3 [12800/124800]
# 訓練進度: 3 [19200/124800]
# 訓練進度: 3 [25600/124800]
# 訓練進度: 3 [32000/124800]
# 訓練進度: 3 [38400/124800]
# 訓練進度: 3 [44800/124800]
# 訓練進度: 3 [51200/124800]
# 訓練進度: 3 [57600/124800]
# 訓練進度: 3 [64000/124800]
# 訓練進度: 3 [70400/124800]
# 訓練進度: 3 [76800/124800]
# 訓練進度: 3 [83200/124800]
# 訓練進度: 3 [89600/124800]
# 訓練進度: 3 [96000/124800]
# 訓練進度: 3 [102400/124800]
# 訓練進度: 3 [108800/124800]
# 訓練進度: 3 [115200/124800]
# 訓練進度: 3 [121600/124800]
# 測試集: 平均損失: 0.2336, 準確率: 19237/20800 (92.5%)
# 第3輪訓練用時: 221.49秒
# 總訓練時間: 658.66秒
# 模型已保存到 models/letter_model_cpu.pt
# 使用cuda進行訓練
# 訓練進度: 1 [0/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 76.71 MiB
# 訓練進度: 1 [6400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [12800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [19200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [25600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [32000/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [38400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [44800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [51200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [57600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [64000/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [70400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [76800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [83200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [89600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [96000/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [102400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [108800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [115200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 訓練進度: 1 [121600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 86.32 MiB
# 測試集: 平均損失: 0.2909, 準確率: 18894/20800 (90.8%)
# 第1輪訓練用時: 33.16秒
# 訓練進度: 2 [0/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [6400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [12800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [19200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [25600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [32000/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [38400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [44800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [51200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [57600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [64000/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [70400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [76800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [83200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [89600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [96000/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [102400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [108800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [115200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 2 [121600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 測試集: 平均損失: 0.2542, 準確率: 19036/20800 (91.5%)
# 第2輪訓練用時: 31.70秒
# 訓練進度: 3 [0/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [6400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [12800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [19200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [25600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [32000/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [38400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [44800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [51200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [57600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [64000/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [70400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [76800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [83200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [89600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [96000/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [102400/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [108800/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [115200/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 訓練進度: 3 [121600/124800]
# [GPU] 使用記憶體: 35.67 MiB
# [GPU] 最⼤使⽤記憶體: 740.41 MiB
# 測試集: 平均損失: 0.2332, 準確率: 19265/20800 (92.6%)
# 第3輪訓練用時: 31.82秒
# 總訓練時間: 96.68秒
# 模型已保存到 models/letter_model_cuda.pt
# 比較結果已保存到 'training_comparison.txt'
# 準確率比較圖已保存到 'accuracy_comparison.png'

# %%
import os
drive_path = '/content/drive/My Drive/'

# %%
from google.colab import drive
drive.mount('/content/drive')

# Check if the Drive path exists
if os.path.exists(drive_path):
    print("Google Drive is mounted successfully.")

    # List items in your main Drive folder
    print("Items in your Drive:")
    for item in os.listdir(drive_path):
        print(item)
else:
    print("Google Drive is not mounted or the path is incorrect.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive is mounted successfully.
# Items in your Drive:
# Colab Notebooks
# forward.gsheet
# frm比重OTC_1_選擇權評價_binomial_model Exchange_Margin_Account_Balance swap i.gsheet
# future 期貨價格.gsheet
# Hedge .gsheet
# Option Greek Delta.gsheet
# Option Greek Theta.gsheet
# option Standard error_cheaptest to deliver_ Geometric Brownian motion_ Margin Account Balance__Optimal hedge Ratio_Callable Bond_ protected put_ covered Call_ Future_ forward foreign Exchange Rate_ swap.gsheet
# portofolio yieled portofolio duration.gsheet
# Present Value _Bayes Theorem_Standard error_cheaptest to deliver_ Geometric Brownian motion_Margin Account Balance_Optimal hedge Ratio_Optimal hedge Ratio_Call.gsheet
# put price within forward.gsheet
# spot rate forward rate par yield discount function (2).gsheet
# spot rate forward rate par yield discount function.gsheet
# study-note binomial black shloe yiel put cal parity.gsheet
# study-note covariance.gsheet
# studyplan_Bayes Garch simple pvalue tvalue explanatory_variable Coefficient error_term multiple_regression_R2 sum_of_squares t statistics observation regression_equation coefficient_slope_df tvalu.gsheet
# swap (2).gsheet
# swap.gsheet
# var correation currency.gsheet
# 無標題簡報.gslides
# mANUAL_新增帳號.gslides
# manual VPN set up.gslides
# manual cits_close_issue.gslides
# 美樂鍋具 對帳單範本 v3.xls
# 從 Google 筆記本匯入 - test to evernote.gdoc
# 從 Google 筆記本匯入 - My first notebook.gdoc
# 從 Google 筆記本匯入 - Notebook 1.gdoc
# 日計畫by time 自動統計 20120317.gsheet
# 無標題的試算表.gsheet
# PMsystem.ppt.gslides
# 康健雜誌 心臟健康一百問.pdf
# V017872_20130116代收清單01.xls
# mobile ptr
# taipei.gmap
# 我儲存的位置.gmap
# page-0003.tif
# test (1).pdf
# test2.pdf
# test.pdf
# page-0003.pdf
# page-0003.doc
# page-0003.doc.gdoc
# test4.pdf after edit.gdoc
# 新進員工須知.doc.gdoc
# mANUAL pchome美樂鍋具對帳副本.gslides
# ._軟體開發方法論.ppt 的副本
# ._投標寶典－台電版 的副本
# 軟體生命週期模型.doc 的副本
# 程式外包合約範本.doc 的副本
# ._程式外包合約範本.doc 的副本
# ._責任指派矩陣.ppt 的副本
# ._軟體生命週期模型.doc 的副本
# 責任指派矩陣.ppt 的副本
# ._政府資訊委外採購手冊（重要參考） 的副本
# ._專案常見風險清單.xls 的副本
# ._板書 的副本
# ._4.0外包專案管理 的副本
# ._免費專案管理軟體 的副本
# ._政府部門資訊委外付款額度配置調查表.doc 的副本
# ._SOC廠商承諾聲明表 的副本
# 專案常見風險清單.xls 的副本
# ._專案建議書範本.doc 的副本
# 政府部門資訊委外付款額度配置調查表.doc 的副本
# ._SOC廠商承諾聲明表-2016-07-14.zip 的副本
# ._5.0廠商評鑑 的副本
# 軟體開發方法論.ppt 的副本
# ._2.0邀商規劃 的副本
# ._.DS_Store 的副本
# ._Project 2003使用手冊 的副本
# ._3.0商源評選與合約簽訂 的副本
# .DS_Store 的副本
# ._1.0可行性分析 的副本
# SOC廠商承諾聲明表-2016-07-14.zip 的副本
# 專案建議書範本.doc 的副本
# ._Code Review 的副本
# 綠領第一屆高峰會.pdf
# Ord_Detail_20181130.xls.gdoc
# Documents
# 201812_C02002.zip
# IMG_4438.jpeg
# 林肯的智慧.pdf
# cover.pdf
# 2019_03_01_02_53_55.pdf
# 2019_02_27_10_51_10.pdf
# 2019_02_27_12_04_16.pdf
# 2019_02_27_12_10_56.pdf
# 2019_02_27_12_24_09.pdf
# 2019_02_27_15_52_36.pdf
# 2019_02_27_16_03_19.pdf
# The Holy Word for Morning Revival Liviticus.pdf
# 保養彩妝 彩妝大師朱正生教你上妝兼護膚.pdf
# 防水工實用便查手冊.pdf
# Analyzing Requirements and Defining Microsoft net solution architectures.pdf
# Developing XML Web Services Using Microsoft ASP.net Workbook.pdf
# Linux as a Webserver Apache Instructor Guide.pdf
# 晨興聖言 禱告與主的行動.pdf
# 2019_02_27_10_32_06.pdf
# 2019_02_27_10_45_16.pdf
# 腦筋急轉彎２５.pdf
# 公共項目管理.pdf
# Linux Intergration with Windows.pdf
# 2019_02_25_19_37_29.pdf
# Linux Network Administration Network Security and Firewalls Student Notebook LX24.pdf
# BAIKAN German.pdf
# Linux as a Webserver Apache Student Notebook LX25.pdf
# 與成功有約.pdf
# 與成功有約.gdoc
# 間接履歷表A_201711_(Security B).doc
# resume example (2).gdoc
# 2014_12_12_12_08_18.pdf
# (講義)20180225個股課.pdf
# 20121116210758.pdf
# DSC_0280-ok.jpg
# DSC_0280.JPG
# 2019_09_14_21_13_26.pdf
# 檔案_001.png
# 2012_12_20_14_19_19.pdf
# 2019_11_14_16_27_01.pdf
# 2019_11_14_16_52_14.pdf
# R
# Python
# bookscan
# evernote
# 20190117 工作驗證與檢討.xlsm.gsheet
# 日計畫by time 自動統計 20200314.gsheet
# 日計畫by time 自動統計 20200218.gsheet
# 日計畫by time 自動統計 20191231.gsheet
# outlook
# value_persue.xlsx
# 日計畫by time 自動統計 20200514.gsheet
# 日計畫by time 自動統計 20200525.gsheet
# 子昂 勞健保、勞退三合一加保申報表(3合1網路版).doc.gdoc
# 退保.pdf
# 勞健保退保申請表.odt
# 勞健保退保申請表.doc
# 「RESUME 間接履歷表A_201711_(Security B) (1).pdf」複本.pdf
# 20200626 銷售戰略的規劃.gdoc
# strategy.jpg
# 森華
# 買冰箱折現.xlsx
# 要不要繼續養鴨_決策樹.xlsx
# 10907_13182186_營業人銷售額與稅額申報書(401).pdf
# 10907_29025780_營業人銷售額與稅額申報書(401).pdf
# 更生_all_201907_202001.pdf
# 更生_all_201907_202007.pdf
# 20200717銷售戰略的規劃.gdoc
# 土壤液化.jpg
# IMG_7142.jpg
# 22101424061.030.pdf
# 2018_11_23_0543170.pdf
# 「Num_18.mp3」複本
# cee3d8caf02d2af90242a8956bec0975f465a4b3-1.docx
# cee3d8caf02d2af90242a8956bec0975f465a4b3-2.docx
# 15ec352ccfc789eb172dc8f6.txt
# 83cfe2791a37f111f0855b61.xlsx
# 3381d5da360cba1aa911da05.vsd
# 1-3勞健單位變更B表1070730.pdf
# 支付命令2.pdf
# to_share_就業中心.jpg
# 勞保明細表.pdf
# FK50956780_20201004152920260.html
# FK50956780_20201004152920260.gdoc
# 2018_Book_PracticalMachineLearningWithPy.pdf
# 2018_Book_PracticalMachineLearningWithPy (1).pdf
# A FUNCTIONAL START TO COMPUTING WITH PYTHON.pdf
# remix-master.zip
# 智能合約實作(一) (1).gslides
# FixedSupplyBasicERC20-master.zip
# 智能合約上課教學 (1).gslides
# 智能合約實作(一).pdf
# 智能合約上課教學.pdf
# 智能合約實作(一).gslides
# 課程大綱.gslides
# 區塊鏈基礎介紹.gslides
# 智能合約上課教學.gslides
# 進階合約使用.gslides
# 智能合約實作(二).gslides
# 智能合約實作(三).gslides
# 智能合約上課教學v2.gslides
# 量子 quantuam
# 1299FDF6-651F-4692-9F24-0CCD27CA1B46.jpg
# icloud
# Current_Steps
# XAMARIN
# AZURE
# blockchain
# SMART GRID
# MyApplication2.zip
# MyApplication.zip
# 2018_08_02_03_59_40 (1).pdf
# 2018_08_02_03_59_40_big.pdf
# 2018_08_02_03_59_40.pdf
# 無標題文件 (2).gdoc
# Dapp-1-201013.pptx.gslides
# Internet.pptx.gslides
# Permission.pptx.gslides
# Storage.pptx.gslides
# 雲端與行動運算
# 無標題文件 (1).gdoc
# Downloads
# Current_Steps insert sol
# solidity_ganesh.zip
# ocp.pdf
# TruffleVoting.zip
# Blockchain Class Demo.zip
# ch04-20201109T020748Z-001.zip
# mario_dice.7z
# mario_dice2.zip
# 台積電青年築夢計畫計畫大綱.gdoc
# 區塊鏈專題題目報告.ppt
# Storage.pptx.pdf
# airbnbsol.jpg
# 206362514_l.jpg
# 架構.gdoc
# blockchain.jpg
# SimpleVoting.zip
# TruffleVoting
# Silvia Tsai_resume.pdf
# 2018_08_02_03_59_40(2).pdf
# Silvia Tsai_resume.gdoc
# 2019_06_17_13_37_00(1).pdf
# Desktop
# survey (2).sol
# survey (2).sol.gdoc
# survey (1).sol
# survey.sol
# survey (1).sol.gdoc
# survey.sol.gdoc
# Notes_201128_093256 (3).jpg
# Notes_201128_093256 (4).jpg
# DolphinAndroid.7z
# 2019_03_19_19_36_55.pdf
# 2020_11_02_04_19_02.pdf
# 打鐵舖_consultant_questionaire.pdf
# 打鐵鋪.gdoc
# payable_data_inreal_testcase_更改後.gsheet
# 附件D.申請者自我檢查表0805_2 (1).gdoc
# ERP 榮國 UAT 2020 (7-14 Dec 2020).v1.20201207.test cases.gsheet
# 1607331661349.jpg
# 打鐵舖.pdf
# 打鐵舖_Project_Timeline_v1.pdf
# 附件D.申請者自我檢查表0805_2.gdoc
# 打鐵舖.gdoc
# Silvia Tsai resume.gdoc
# 營業稅計算.gsheet
# 天星-hr文中.pdf
# SBIR.gdoc
# 無標題文件.gdoc
# 天星ERP成本會計spec.gdoc
# IMG_6790.JPG
# 正在傳送電子郵件 2020_09_24_09_26_23.pdf
# 傳媽媽的醫療明細表.gsheet
# Mask 大道診所.gsheet
# Mask 乃聖.gsheet
# 2021年2月21號花費.gsheet
# 未命名試算表 (4).gsheet
# 勞工局申訴.gdoc
# 無標題試算表 (3).gsheet
# 鼓山.gsheet
# 左營.gsheet
# 旗山.gsheet
# 前鎮.gsheet
# 鳳山.gsheet
# 依照勞動基準法第 59條第一至三款、 職業災害勞工保護法 第7條、 民法第184條第2項規定， 相對人應給付申請人相關醫療費用、 工資補償、 看護費 及精神慰撫金。.gdoc
# 20210219 銷售戰略規劃.gdoc
# 未命名文件 (45).gdoc
# 未命名文件 (44).gdoc
# 無標題試算表 (2).gsheet
# 無標題試算表 (1).gsheet
# Health.gdoc
# 擦拭 用消毒藥水辦公室外蟲媒 慢性急性.gdoc
# 職安.gdoc
# 以下檔案的副本： 抗告 (1).gdoc
# 抗告.gdoc
# 以下檔案的副本： 抗告.gdoc
# 王大哥，我是跟您在桃園二結義，用蕃茄醬結拜的乾妹妹，您還記得我嗎？妹蔡斐婷敬上.gdoc
# 未命名文件 (43).gdoc
# Jira owner
# Cse timesheet
# Python back test good strategy for investment.gdoc
# 樂購員工薪資明細表(業務部)－蔡斐婷.xlsx
# 薪水202102樂購.gsheet
# 時間.gsheet
# 未命名文件 (42).gdoc
# 未命名文件 (41).gdoc
# 未命名文件 (40).gdoc
# 公務人員履歷表(簡式).gdoc
# 公務人員履歷表填寫範例.gdoc
# 公務人員履歷表(一般).gdoc
# dl-53643-857e761b-ebe6-49f8-b7ca-d0cb2f6712be.html
# 20210402 銷售戰略的規劃.gdoc
# 衛生福利部改善公共安全設施補助計畫.gsheet
# 無標題試算表.gsheet
# 20210409 銷售戰略的規劃.gdoc
# Workshop.gsheet
# Wifi 55857767 hostel.gdoc
# 未命名文件 (39).gdoc
# 未命名文件 (38).gdoc
# 正在傳送電子郵件 1-2勞、退合一退保申報表_1091103.pdf
# Resume
# 永生.gdoc
# 未命名試算表 (3).gsheet
# 未命名試算表 (2).gsheet
# TRUFFLE_VOTING
# Videoleap-0E16304D-7C9C-4001-A5F0-9BD2E2891439.MOV
# Video
# 未命名文件 (37).gdoc
# SIIR 5w3h.gdoc
# 06.09.2021_0840上午.m4a
# Lifestudy
# mom_investment 媽媽股票投資.gsheet
# Created by V Recorder:https:  play.google.com store apps details?id=screenrecorder.recorder.editor
# 約壹 光.gdoc
# 彼得前 光.gdoc
# 希伯來書 光.gdoc
# 帖撒羅尼迦前書 第 五 章 光.gdoc
# 胸甲 -公義如胸甲 義的胸甲 穿上信和愛的胸甲.gdoc
# 救恩的頭盔.gdoc
# 啟示錄光.gdoc
# 箭 火燒的箭 箭射出如閃電.gdoc
# 經　文 聖經中的異象.gdoc
# 耶  13章23節 古實人 豹紋 獸.gdoc
# 哥1亞倫，和他的兒子拿答、亞比戶、以利亞撒、以他瑪，一同就近你，可以作2祭司事奉我。.gdoc
# Joshua.gdoc
# 中文綱要(無經文).pdf
# 英文綱要(無經文) (1).pdf
# 中英文綱要(附經文).pdf
# 英文綱要(無經文).pdf
# Money Manager v0.0.1 - demo - EDITABLE [EXAMPLES] 的副本.gsheet
# tableau
# 第六週 週三.gdoc
# 第六週■週二.gdoc
# 未命名文件 (36).gdoc
# ***大黃蜂.gdoc
# 第六週■週一.gdoc
# 20210718.gsheet
# Silvia Tsai resume.pdf
# 20210721.gdoc
# 20210709.xls
# 20210710.xls
# 以賽亞書 toshare.gdoc
# 這律法不可離開你的口，總要晝夜默想.gdoc
# 但支派.gdoc
# 約書亞紀 路得紀 誓師祭 第一周綱要.gsheet
# 第二周 周一.gdoc
# Josh 約書亞記.txt.gdoc
# 未命名文件 (35).gdoc
# yhy
# server.py
# Functions.ipynb
# Untitled0.ipynb
# statements.ipynb
# Untitled document (14).gdoc
# 政府部門資訊委外付款額度配置調查表.doc
# Code Review
# 責任指派矩陣.ppt
# 專案常見風險清單.xls
# 軟體生命週期模型.doc
# 程式外包合約範本.doc
# SOC廠商承諾聲明表-2016-07-14.zip
# 專案建議書範本.doc
# 軟體開發方法論.ppt
# Copy of 身分證 蔡斐婷 變更公司登記住址.pdf
# Untitled document (13).gdoc
# Pmp
# Law
# App
# Kitchen
# FunShow011.php-B=42_15_15_0_1.htm.gdoc
# 穿搭設計書.pdf
# 夏目吉信.pdf
# 疥癬 小狗皮膚病.gdoc
# 地球上最健康的150種食材.pdf
# 2018_09_16_00_15_37.pdf
# Chineses Medicine
# 002fopb9p8ThgyUy9PSq7fJrQ (1)
# 002fopb9p8ThgyUy9PSq7fJrQ
# 聖經綱目.pdf
# 申言稿.gdoc
# 申言.gdoc
# 未命名文件 (34).gdoc
# AI
# Android
# Backup
# bible
# BLOCKCHAIN
# 日計畫by time 自動統計 20220420.xls.gsheet
# 日計畫by time 自動統計 20220922.xls.gsheet
# 日計畫by time 自動統計 20230624.xls.gsheet
# 日計畫by time 自動統計 20201229.xls.gsheet
# 日計畫by time 自動統計 20201230.xls.gsheet
# 日計畫by time 自動統計 20201231.xls.gsheet
# 日計畫by time 自動統計 20211101.xls.gsheet
# 日計畫by time 自動統計 20211103.xls.gsheet
# 日計畫by time 自動統計 20190127.xls.gsheet
# 日計畫by time 自動統計 20190128.xls.gsheet
# 日計畫by time 自動統計 20190129.xls.gsheet
# 日計畫by time 自動統計 20190130.xls.gsheet
# 日計畫by time 自動統計 20190131.xls.gsheet
# 日計畫by time 自動統計 20190312.xls.gsheet
# 日計畫by time 自動統計 20190314.xls.gsheet
# 日計畫by time 自動統計 20190315.xls.gsheet
# 日計畫by time 自動統計 20190316.xls.gsheet
# 日計畫by time 自動統計 20191212.xls.gsheet
# 日計畫by time 自動統計 20191213.xls.gsheet
# 日計畫by time 自動統計 20180219.xls.gsheet
# 日計畫by time 自動統計 20180220.xls.gsheet
# 日計畫by time 自動統計 20180221.xls.gsheet
# 日計畫by time 自動統計 20180222.xls.gsheet
# 日計畫by time 自動統計 20180223.xls.gsheet
# 日計畫by time 自動統計 20180224.xls.gsheet
# 日計畫by time 自動統計 20180506.xls.gsheet
# 日計畫by time 自動統計 20180507.xls.gsheet
# 日計畫by time 自動統計 20180508.xls.gsheet
# 日計畫by time 自動統計 20170408.xls.gsheet
# 日計畫by time 自動統計 20170409.xls.gsheet
# 日計畫by time 自動統計 20190209.xls.gsheet
# 日計畫by time 自動統計 20190210.xls.gsheet
# 日計畫by time 自動統計 20190211.xls.gsheet
# 日計畫by time 自動統計 20190212.xls.gsheet
# 日計畫by time 自動統計 20190213.xls.gsheet
# 日計畫by time 自動統計 20190214.xls.gsheet
# 日計畫by time 自動統計 20190426.xls.gsheet
# 日計畫by time 自動統計 20190427.xls.gsheet
# 日計畫by time 自動統計 20190428.xls.gsheet
# 日計畫by time 自動統計 20190429.xls.gsheet
# 日計畫by time 自動統計 20150617.xls.gsheet
# 日計畫by time 自動統計 20150422.xls.gsheet
# HRSS.exe
# 「治療新希望你射療法 2014_09_26_09_17_37.pdf」複本.pdf
# 「2023_01_23_11_55_51.pdf」複本.pdf
# strategy
# hymn
# Lesson Learned
# DCIM
# 食譜 家常菜
# Scan Aug 8, 2023 (5).pdf
# Scan Aug 8, 2023 (7).pdf
# Scan Aug 8, 2023 (1) (1).pdf
# Scan Aug 8, 2023 (1).pdf
# IMG_5306 (1).PNG
# IMG_5306.PNG
# 截圖 2023-12-20 下午6.12.59.png
# Reply boss.gdoc
# 更換 律師 李.gdoc
# 美斯.gdoc
# Church.gdoc
# 總結.gdoc
# 2023年感恩特會第二週1.pdf
# 舅舅對不起.gdoc
# iPhone X ever note email.gdoc
# 20231229 銷售戰略規劃.gdoc
# 心好累 part2.gdoc
# Untitled document (12).gdoc
# 未命名文件 (33).gdoc
# 未命名文件 (32).gdoc
# 好市多 (1).gsheet
# location dumpling.pdf
# location dumpling.gsheet
# 2019_02_05_23_20_01.pdf
# 好市多.gsheet
# 鴻海人工智慧機器人 英文resume.gdoc
# 以下檔案的副本： 鴻海人工智慧機器人 英文resume.gdoc
# 數位健康工程師 鴻海via Fei-Ting Tsai.gdoc
# 禱告 (2).gdoc
# 登山.gdoc
# 禱告 (1).gdoc
# 安親.gdoc
# 禱告.gdoc
# 計帳.gsheet
# 其他專長.gdoc
# 血藝.gdoc
# 無炒手 快Scan Aug 8, 2023 (6).pdf
# via Fei-Ting Tsai.gdoc
# 未命名文件 (31).gdoc
# 請假單.gdoc
# 請假單.pdf
# China.gdoc
# 蒜蓉醬.gdoc
# kitchen2.gsheet
# SmartSelect_20240329-105149_Messenger.jpg
# Untitled document (11).gdoc
# 未命名文件 (30).gdoc
# 未命名文件 (29).gdoc
# 未命名文件 (28).gdoc
# 照顧寵物的心靈療法.gsheet
# 未命名文件 (27).gdoc
# 未命名文件 (26).gdoc
# 未命名文件 (25).gdoc
# 未命名文件 (24).gdoc
# 謝.gdoc
# 沒事.gdoc
# 面.gdoc
# 75麵.gdoc
# 未命名文件 (23).gdoc
# 2018_03_28_16_15_39.pdf
# mommy laid egg 2018_03_28_16_15_39.pdf
# 童書
# 蛋糕3.pdf
# 2018_03_28_16_42_03.pdf
# 2017_09_14_15_17_23.pdf
# 怪咖1_已辨識.pdf
# 怪咖成功法則.pdf
# 怪咖成功法則 2.pdf
# 未命名文件 (22).gdoc
# 蛋糕.gdoc
# 未命名文件 (21).gdoc
# 未命名文件 (20).gdoc
# (iQ-F教育訓練手冊) 基礎02 (1).pdf
# (iQ-F教育訓練手冊) 基礎02.pdf
# 08PLC 入門程式練習題目ok.pdf
# 08PLC 入門程式練習題目ok (1).pdf
# FX5U 第一堂課 20240711.gx3
# FX5U 第一堂課 20240711 (1).gx3
# FX5U 第一堂課 習題01 20240711.gx3
# FX5U 第一堂課 習題01 20240711 (1).gx3
# 碳
# AI機器人與圖控系統整合(桃園)第1期(第二次甄試).pdf
# 職前訓練考試
# 勞動力機器人.gdoc
# 半導體
# Whatever.gdoc
# 未命名文件 (19).gdoc
# 受訓學員基本資料卡-報名表-1.doc
# 受訓學員基本資料卡-報名表.docx
# 成功大學
# 未命名文件 (18).gdoc
# 智慧行動.gsheet
# 掃描 2024年8月15日.pdf
# 未命名文件 (17).gdoc
# 饒智銘.gdoc
# 未命名文件 (16).gdoc
# grid.gdoc
# 未命名文件 (15).gdoc
# caplito monica chatgpt compare.gdoc
# 精密機械班、CNC銑床班、電腦網路工程實務班.pdf
# CNC數控班、電腦網路工程實務班.pdf
# 電腦網路工程實務班專業學科試題範例.pdf
# 2010_Book_ProSqlAzure (1).pdf
# 2010_Book_ProSqlAzure.pdf
# APPCC
# Business
# CSTAPLR Issues (K&S JIRA) report.files
# Card_thankyou
# Low-Carbon Life with Sunshine.pdf
# 2017台达杯国际太阳能建筑设计竞赛获奖作品集 阳光●颐养_Part2_Part1-1.pdf
# 2017台达杯国际太阳能建筑设计竞赛获奖作品集 阳光●颐养_Part2_Part1-2.pdf
# 2017台达杯国际太阳能建筑设计竞赛获奖作品集 阳光●颐养_Part3.pdf
# 2017台达杯国际太阳能建筑设计竞赛获奖作品集 阳光●颐养_Part1.pdf
# 未命名文件 (14).gdoc
# Self introduction.gdoc
# openai password.gdoc
# self introduce 3min.gdoc
# 未命名文件 (13).gdoc
# 綠茶.gdoc
# self introduce 20241011 件.gdoc
# my workshop.gdoc
# 未命名文件 (12).gdoc
# 未命名文件 (11).gdoc
# 未命名文件 (10).gdoc
# 天塌下來 自有長的撐住.gdoc
# loggo_yourhealth_we_care.png
# whale_channels4_banner (1).jpg
# AdobeStock_181163094.jpeg
# 2.LabView數值 (1).pdf
# 2.LabView數值.pdf
# 1-1.LabView工作環境 (1).pdf
# 1-1.LabView工作環境.pdf
# 2024年10月22日訓練日誌.gdoc
# 03.RCA605控制器介紹_王誌隆20241029.pdf
# 03.RCA605控制器介紹_王誌隆20241029 (1).pdf
# silvia2.jpg
# What is Arduino.gdoc
# 第一章  可程式控制器硬體介紹_自保持20241105.pdf
# 第二章  可程式控制器軟體編輯與操作20241105.pdf
# 2018_Book_BeginningRoboticsWithRaspberry.pdf
# 2018_Book_BeginningRoboticsWithRaspberry (1).pdf
# GoogleDriveSetup.exe
# npp.8.7.1.Installer.x64.exe
# 第4章 蜂鳴器與音樂20241106.pdf
# OLDVERSION.hrb
# lab.hrb
# PACKAGE.hrb
# REL.hrb
# LIN LIN_REL.hrb
# LIN_XY.hrb
# 點為參數累加.hrb
# circ.hrb
# circ2.hrb
# rub_bank.hrb
# 無限.hrb
# 機器手臂 座標.gsheet
# infinity.hrb
# Program
# java
# 第4章 蜂鳴器與音樂20241108.pdf
# 第5章 數位輸入_開關20241108.pdf
# 美工軟體
# 04.RA605軟體介紹_HRSS2.1.20_王誌隆-5_結構迴圈敘述（WHILE...、IF...THEN、SWITCH、FOR）20241111 (1).pdf
# 04.RA605軟體介紹_HRSS2.1.20_王誌隆-5_結構迴圈敘述（WHILE...、IF...THEN、SWITCH、FOR）20241111.pdf
# 04.RA605軟體介紹_HRSS2.1.20_王誌隆-6（LOOP林老師、REPEAT、GOTO、CALCULATE）WAIT FOR、協作、COUNTER、TIMER、OUTPUT_20241111.pdf
# 04.RA605軟體介紹_HRSS2.1.20_王誌隆-6（LOOP林老師、REPEAT、GOTO、CALCULATE）WAIT FOR、協作、COUNTER、TIMER、OUTPUT_20241111 (1).pdf
# 5-2. Labview Case 、 Event 及Sequence架構 (1).pdf
# 新增資料夾 (2)
# _PLC
# 第一章  可程式控制器硬體介紹_自保持20241113 (1).pdf
# 完整_承岳 (1).mp4
# 完整_承岳.mp4
# enum_1.vi
# plc_cylinder_Advantech.vi
# Untitled.png
# launch.bat
# 2.png
# 6. LabView Sting字串 (1).pdf
# 6. LabView Sting字串.pdf
# 1.png
# 3.png
# 7.Cluster叢集 (1).pdf
# 7.Cluster叢集.pdf
# labviewf-20241114T052956Z-001 (1).zip
# labviewf-20241114T052956Z-001.zip
# Untitled 2.vi
# Untitled 1.vi
# cylinder 0.png
# cylinder 1.png
# run2.vi
# 承越學長_山寨版.vi
# 承越學長_山寨版.rar
# 承越學長_山寨版 (1).rar
# Python自學聖經(第二版)學習資源 (1).zip
# Python自學聖經(第二版)學習資源.zip
# 新文字文件.gdoc
# labviewf
# 第5章 數位輸入_開關20241108 (1).pdf
# 第4章 蜂鳴器與音樂20241106 (1).pdf
# 第4章 蜂鳴器與音樂20241108 (1).pdf
# 第6章 類比輸入_感測器(VR、CdS)20241115.pdf
# 6739a057-5d24-800a-be90-820215bbd3c1
# 7.png
# COUNTER.hrb
# 三角 四方.hrb
# sin cosin tander call tender sec callsec.hrb
# test.hrb
# test (1).hrb
# 5.png
# IMG_9528.PNG
# 第4_7章 arduino.pdf
# 夾爪.png
# sweep.gdoc
# 第7章 伺服馬達與控制20241121.pdf
# 第4_7章 arduino reco.pdf
# 10-1動手做《超音波測量距離》10-2動手做《倒車雷達警示》20241121.pdf
# 4.png
# car_beep2.abp
# car_trial 6.gdoc
# ultrasonic SR04.gdoc
# car_beep_and _turn left.gdoc
# car_beep_ok.gdoc
# randomseed by analog.gdoc
# 未命名文件 (9).gdoc
# 願望清單.gsheet
# test7.py
# test8.py
# Green Building
# 2017台达杯国际太阳能建筑设计竞赛获奖作品集 阳光●颐养_Part2_Part1 (1).pdf
# 藍芽.abp
# 藍芽2.abp
# 銷售戰略20241130.gdoc
# 第四章  順序功能圖與步進階梯圖20241129.pdf
# arduino 繼電器 -->電磁閥 --> cylinder relay control.gdoc
# 超音波辨識+馬達+祝你聖誕快樂.abp
# music_player_by_google_voice.txt
# music_3_5_9.gdoc
# 未命名文件 (8).gdoc
# RA605 考試題目 1.gdoc
# 圖表模擬.vi
# WaveformChart.vi
# 紅綠燈.vi
# 未命名文件 (7).gdoc
# 樹莓串aws 串聯arduino.gdoc
# Arduino 聽命令開關燈或電扇冷氣.gdoc
# Esp8266 讓mqtt ok.gdoc
# Esp32 sample codes.gdoc
# 樹莓安裝 mqtt.gdoc
# Call 聽話程式.gdoc
# 未命名文件 (6).gdoc
# 039.ETH網路測試_用教點的方式.hrb
# Caterpillar_1.2.4.zip
# HRSS_3.3.29.17604_x86_offline.zip
# 043.GET_MOTION_STATUS.hrb
# HRSS 3.3.24.12085_x86 offline.rar
# HRSS_2.1.29.2772_RA605_offline_無程式.rar
# 04.RA605軟體介紹_HRSS2.1.20_王誌隆-9（CONNECT奇峯、特殊指令_DANCE+BRAKE）20241216.pdf
# 040.DANCE+BRAKE.hrb
# 聖誕快樂評量.abp
# labview 徐俊麟.gdoc
# 未命名文件 (5).gdoc
# Kenny
# PLC 第四章  順序功能圖與步進階梯圖.pdf
# PLC  第三章  可程式控制器基本指令應用_互鎖20241113 (1).pdf
# PLC  第三章  可程式控制器基本指令應用_互鎖20241113.pdf
# PLC  第二章  可程式控制器軟體編輯與操作20241113 (1).pdf
# PLC  第二章  可程式控制器軟體編輯與操作20241113.pdf
# PLC 第一章  可程式控制器硬體介紹_自保持20241113.pdf
# machine vision
# 機電整合-F.綜合練習-臥式滑台設計_補充緊停開關的接法_王誌隆20250103.pdf
# 未命名文件 (4).gdoc
# 夢
# RAG_AI_Slides.pptx
# 名片 2025年1月31日.pdf
# 2018_12_29_10_26_52.pdf
# 未命名試算表 (1).gsheet
# 蔡斐婷_在訓學員個人考勤明細表.gsheet
# uR
# robot
# arduino
# 3D
# PLC
# Copy of 超音波辨識+馬達+祝你聖誕快樂 (4).abp
# Copy of 聖誕快樂評量.abp
# Copy of 超音波辨識+馬達+祝你聖誕快樂 (3).abp
# Copy of 聖誕_20241217 v1.abp
# Copy of 超音波辨識+馬達+祝你聖誕快樂 (2).abp
# Copy of q9.abp
# Copy of blink forever (1).abp
# Copy of 評量.q1 q8abp
# Copy of VR stop +祝你聖誕快樂 (1).abp
# Copy of 聖誕_20241217.abp
# Copy of scoop 8_.abp
# Copy of car_beep2_arduino (1).abp
# Copy of test.abp
# Copy of 藍芽2 (1).abp
# Copy of scoop 8_1.abp
# Copy of car_beep2_arduino.abp
# Copy of 超音波辨識+馬達+祝你聖誕快樂 (1).abp
# Copy of 超音波辨識+馬達+祝你聖誕快樂.abp
# Copy of VR stop +祝你聖誕快樂.abp
# Copy of scoop.abp
# Copy of infra_ray_3 (2).abp
# Copy of infra_ray_1 (2).abp
# Copy of 6-2+6-2.5_綜合 (3).abp
# Copy of 6-2+6-2.5_綜合(1).abp
# Copy of infra_ray (2).abp
# Copy of clawservotune92 (1).abp
# Copy of whatever (1).abp
# Copy of infra_ray_2 (2).abp
# Copy of 藍芽.abp
# Copy of 藍芽2.abp
# Copy of claw (1).abp
# Copy of light_led_input_by_monitor_windows (1).abp
# Copy of 6-2+6-2.5_綜合 (2).abp
# Copy of infra_ray_3(1).abp
# Copy of 機械開關 (1).abp
# Copy of INFRA2 (1).abp
# Copy of vr (1).abp
# Copy of blink forever add 1 button 按鈕停 (1).abp
# Copy of draw_VR (1).abp
# Copy of VR_control_led_buzzer (1).abp
# Copy of serial_monitor_光敏電阻 (1).abp
# Copy of 5-3.millis()指令消除開關彈跳 (1).abp
# Copy of INFRA (1).abp
# Copy of ar (1).abp
# Copy of car_beep2(2).abp
# Copy of infra_ray_1(1).abp
# Copy of 光敏電阻 (1).abp
# Copy of car_beep2(1).abp
# Copy of infra_ray_2(1).abp
# Copy of infra_ray(1).abp
# Copy of claw.abp
# Copy of infra_ray_3 (1).abp
# Copy of infra_ray (1).abp
# Copy of infra_ray_1 (1).abp
# Copy of car_beep2 (2).abp
# Copy of clawservotune92.abp
# Copy of infra_ray_1.abp
# Copy of infra_ray_2 (1).abp
# Copy of infra_ray_3.abp
# Copy of infra_ray_2.abp
# Copy of 機械開關.abp
# Copy of infra_ray.abp
# Copy of INFRA2.abp
# Copy of car_beep2 (1).abp
# Copy of 光敏電阻.abp
# Copy of VR_control_led_buzzer.abp
# Copy of serial_monitor_光敏電阻.abp
# Copy of car_beep2.abp
# Copy of INFRA.abp
# Copy of 6-2+6-2.5_綜合 (1).abp
# Copy of whatever.abp
# Copy of vr.abp
# Copy of 5-3.millis()指令消除開關彈跳.abp
# Copy of blink forever.abp
# Copy of draw_VR.abp
# Copy of blink forever add 1 button 按鈕停.abp
# Copy of light_led_input_by_monitor_windows.abp
# Copy of ar.abp
# Copy of 6-2+6-2.5_綜合.abp
# 初階機器人工程師術科-試題一.gdoc
# dance_hrb.gdoc
# DANCE.HRB.gdoc
# Untitled spreadsheet (1).gsheet
# sop
# 圖片
# raspberry
# 未命名試算表.gsheet
# 3.jpg
# 2 (1).png
# Untitled-1-1.jpg
# Untitled-1.jpg
# Untitled-1@1x_1-1.jpg
# Untitled-1@1x_1.jpg
# 4.jpg
# Untitled-1.psd
# 5.jpg
# silvia_whale.psd
# self introduc.gdoc
# 瞧瞧我的 Canva 設計傑作！
# PSX_20250218_222122.png
# 401
# 台灣居民預辦入境登記通知書.pdf
# 台胞證 台灣居民
# vpn
# enhanced_image1.jpg
# Untitled document (10).gdoc
# context protocol vs OpenAI 的 Function Calling & RAG（檢索增強生成）.gdoc
# 3034_d7c39ab0.gdoc
# 員工報到卡(1).gdoc
# Untitled document (9).gdoc
# Untitled presentation.gslides
# test-1743010307.txt
# test k8s.gdoc
# gdrive-pv-deployment.yaml
# google-drive-deployment-with-tolerations.yaml
# test-1743013245.txt
# test-improved-1743019079.txt
# Untitled document (8).gdoc
# 未命名文件 (3).gdoc
# 未命名文件 (2).gdoc
# 未命名文件 (1).gdoc
# checklist
# LabVIEW Vision Assistance、OpenCV，以及 YOLO 在 FPGA 上的應用。.gdoc
# 先進機器人視覺整合平台 機器人與 NVIDIA 平台整合.gdoc
# 運用 Kubernetes 與邊緣運算整合 ESP32 Arduino 裝置：架構設計.gdoc
# Untitled document (7).gdoc
# Untitled document (6).gdoc
#  FPGA 與 GPU 從烏克蘭到太空 — AWS 與機器人無所不在.gdoc
# tune the lecture for this topic: 機器人世代的崛起：AI 及機器人....gsheet
# Untitled spreadsheet.gsheet
# 機器人世代的崛起：AI 及機器人技術大解析.gdoc
# 以下是為 Universal Robots 台灣業務團隊 設計的 協作機器人銷售演講框架，結合全球部署經驗與 AI 創新應用，突出 即時商業價值 與 產業升級路徑：.gdoc
# 生成式機器人世代.gdoc
# goldengate kafka.gdoc
# ZDM Migration Automation Script
# .gdoc
# Managing Data as a Product (1).pdf
# Managing Data as a Product.pdf
# 私有鏈解決區塊鏈挑戰提案書.gdoc
# Blockchain: A Practical Guide to Developing Business, Law, and Technology Solutions.gdoc
# 未命名文件.gdoc
# 數位雙生 (Digital Twin) .gdoc
# 《數位孿生：產業應用案例與未來展望》.gdoc
# digital twin :太陽能板數位孿生模型創建.gdoc
# digital twin arduino AWS系統提案.gdoc
# HIPAA NIST.gdoc
# 基于数字孿生与边缘深度学习的糖尿病患者心血管健康监测系统.gdoc
# AWS digital twin 增强提案.gdoc
# v2 AWS 數位孿生戰略強化提案：智慧醫療與工業物聯網整合平台.gdoc
# JavaScript 框架幫助金融和醫療保健組織實施法.gdoc
# digital twin development and deployment on cloud 英文-中文索引.gdoc
# Untitled document (5).gdoc
# 重新定義製造智能化.gdoc
# Untitled document (4).gdoc
# CloudMatrix 384 from 華為 vs nvidia gb200 nvl72 with....gdoc
# 天下雜誌帳號.gdoc
# 現金為王 + 加元 澳元 歐元.gdoc
# 對「現金為王 + 加元 澳元 歐元組合」策略的深度評析.gdoc
# 破局與立新：亂世中的製造突圍戰略—從產業變局到智慧製造的系統思維.gdoc
#  生成式 AI 技術發展與智慧產業應用.gdoc
# 聚焦 AI 製造：借力微型手臂與 AI 智能資源打造高效生產模式.gdoc
# 開放創新，建立多元 AI 生態系.gdoc
# AI 驅動的智慧製造：提升效率與精度的未來.gdoc
# 如何用GPU算力把機器人艦隊變成印鈔機.gdoc
#  讓工廠開口說話—人懂系統的節奏，一起奏出決策的旋律.gdoc
# 缺工時代下的 AI 應用—從智能對話服務到數位轉型.gdoc
# 資料湖 vs. 向量資料庫 vs 資料倉儲vidia Tensor-RT vs AWS SageMaker.gdoc
# 雲深處科技.gdoc
# Untitled document (3).gdoc
# 4. Building Personal Assistants _ LangChain for Life Sciences and Healthcare.pdf
# brew.gdoc
# https:  www.gdoc
# 能源高效邊緣式實時醫療支持系統提案.gdoc
# FastAPI 路由與非同步護欄註解
# ai agent nemo microservice on k8s nim operator.gdoc
# Module Context Pipeline Server (FastAPI)
# MCP Module Context Pipeline 伺服器.gdoc
# NVIDIA k8s-nim-operator.git.gdoc
# 9261f239-30e0-4e4b-927c-b7d6450d8060695817802964614862
# 螢幕快照 2025-04-29 21-47-09.png
# 螢幕快照 2025-04-29 22-36-28.png
# 10246.jpg
# 螢幕快照 2025-04-30 18-18-38.png
# 螢幕錄影 2025年四月30日 18時22分38秒.webm
# Tokenization 寫字樓.gdoc
# NIM OPERATOR.gdoc
# llm  SOFTWARE OPENSOURCE.gsheet
# "kind: InferenceService".gdoc
# KServe InferenceService.gdoc
# 用人形機器人 來製造 人形機器人.gdoc
# 螢幕快照 2025-05-01 06-17-00.png
# 医疗影像工作流程和医学成像模态（X光 MRI CT等）优化的NVIDIA Holoscan SDK.gdoc
# 帕金森氏症分類 (語音) - 模擬 Holoscan 管線
# 實時帕金森氏症分類 (Holoscan SDK)
# index of digital twin.gdoc
# 整合NVIDIA Holoscan SDK的帕金森病实时分类系统.gdoc
# 螢幕快照 2025-05-03 20-46-12.png
# martin_sagayam_good_to_follow.pdf
# subhash chandra.pdf
# Joseph J. Bambara.pdf
# kavita saini.pdf
# mika ylianttila5g security.pdf
# peter membrey.pdf
# julien mattei.pdf
# 云计算.pdf
# behavior trees in robotics and ai .pdf
# vSphere VMware 5 Jumpstartpdf.pdf
# melanie swan.pdf
# docker blockchain4.png
# 71Y6bZ6U2rL._SL1499_.jpg
# 来自医疗保健中AI多个纪律的医生的用户故事.pdf
# blockchain.pdf
# ram charan.pdf
# 生物医学和健康信息学中的大数据分析和机器智能.pdf
# 用于网络安全的应用密码.pdf
# 基于内容的图像检索研究 计算机视觉中,用于现实世界的优化问题.pdf
# Machine Learning and Angiogenesis in Cancer _ Integrating Metaheuristics in Computer Vision for Real-World Optimization Problems.pdf
# nassim khaled.pdf
# 螢幕快照 2025-05-04 10-27-42.png
# Untitled document (2).gdoc
# 螢幕快照 2025-05-04 10-42-01.png
# NVIDIA K8s 开发 LLM 运营商 _ NVIDIA NGC1.pdf
# Clara Holoscan SDK 整合即時 AI 於儀器.gdoc
# 医生关于医疗保健中生成式AI的用户故事”.pdf
# Clara holoscan 機器人世代崛起：NVIDIA 引領 AI & 機器人技術革新 (主....gsheet
# iot 特徵sensing intelligence connectivity communication.pdf
# 螢幕快照 2025-05-05 07-28-01.png
# 機器學習技術於醫療數據分析.gdoc
# sample python codes.gdoc
# sample python codes.pdf
# 螢幕快照 2025-05-05 16-09-52 (1).png
# 螢幕快照 2025-05-05 16-09-52.png
# 螢幕快照 2025-05-06 05-02-44.png
# docker_zemelak.png
# docker_zemelak2
# Docker Whale Blockchain Illustration - Claude.gdoc
# smart grid Draft Proposal Hardware Specifications for Integrating Machine Learning, Deep Learning, and IoT in Smart Grids and Powe.md.gdoc
# airobot  with 5G Security and IoTML in Smart Agriculture.md.gdoc
# Machine Learning Algorithms for Medical Data Analysis.md.gdoc
# cyber security.md.gdoc
# ansible VMware vSphere .gdoc
# WSN 概念模擬 (Python) (1)
# WSN 概念模擬 (Python)
# Bash在Web应用渗透测试.gdoc
# sudo apt-get install apache2.gdoc
# 5g security
# ai medcare bpm 75.gdoc
# 骨骼健康管理中的AI整合.gdoc
# local robot controller LRC.gdoc
# 隱私保護資料管理系統提案.gdoc
# data freshness.gdoc
# Poisoning Evasion Extraction Inference .gdoc
# nvidia
# Untitled document (1).gdoc
# MCP + WBAN.gdoc
# github bio resume.gdoc
# openai api-keys.gdoc
# spring ai security.gdoc
# lamda.gdoc
# os.environ["OPENAI_API_KEY"] = "MY_KEY".gdoc
# 使用 SDR 攻擊無線系統 fpga.gdoc
# 全景健康生物辨識技術.gdoc
# car hacking.gdoc
# Jieba 分詞模式演示
#  Python 中的時間序列分析.gdoc
# socket timeout.gdoc
# ai agent in action.gdoc
# MATLAB Simulink 中進行 AI 建模.gdoc
# ai-projects
# Copy of PVE 虛擬環境 GPU Passthrough 研究-080525-133325.pdf
# 11404_29025780_營業人銷售額與稅額申報書(401)_.pdf
# Kubernetes: Up and Running 1.gdoc
# k8s up and runing 3.gdoc
# K8S UP AND RUNNING 5.gdoc
# K8S UP AND RUNNING 4.gdoc
# k8s up and runing 6.gdoc
# k8s up and runing 4.gdoc
# 10 ChatGPT Prompts.gdoc
# Untitled document.gdoc
# THE DARK SIDE OF DIGITAL.gdoc
# react.gdoc
# Fhir gpdr hippa.gdoc
# 2017台达杯国际太阳能建筑设计竞赛获奖作品集 阳光●颐养_Part2_Part1.pdf
# Num_18.mp3
#  營業稅網路申報.gdoc
# lawyer.gdoc
# 不動產估價上課錄音連結.gdoc
# 倍達資訊稅務.gdoc
# 20090619森華款項.gdoc
# 專案幕標.gdoc
# 免費講座「估價師與地政公職的現在與未來」，課程包含不動產估價師未來的發展空....gdoc
# 基本資料(文桃).gdoc
# upload1.gdoc
# 倍達資訊 面試題.gdoc
# 履歷表(晚上兼職).gdoc
# 樂購國際 (1).gdoc
# 樂購國際.gdoc
# 網路開店時程.gdoc
# 網路商店成本估算.gdoc
# PChome商店街.gdoc
# U90715334.gdoc
# v017872_20090916對帳單明細表01.gsheet
# 產品名稱: 滷鴨腸.gdoc
# 薛大哥您好;.gdoc
# 產品名稱: 滷鴨脖子.gdoc
# 產品名稱: 滷小豆干    重量:約100克.gdoc
# pchome商店街主要工作事項.JPG.gdoc
# resume.gdoc
# 樂購DM (1).gdoc
# 收集家人朋友喜歡的東西.gsheet
# 樂購DM.gdoc
# A＆E唇蜜 (1).gdoc
# 紐西蘭E&W公司與華紐公司.gdoc
# A＆E唇蜜.gdoc
# ※※樂購網絡銷售伯妮保養品價目表.gdoc
# B-05--臉部去角質按摩凝膠.gdoc
# B-06--玻尿酸保濕化妝水.gdoc
# B-07--青春收斂平衡水.gdoc
# B-16--珍珠抗齡霜.gdoc
# B-19--防水保濕隔離乳.gdoc
# B-25--去角質按摩凝膠.gdoc
# 樂購名片與DM.gdoc
# 樂購DM01.gdoc
# pchome商品售價計算式.gsheet
# 小黃瓜氨基酸面膜.gdoc
# 紅酒保濕嫩膚面膜.gdoc
# 商品流量.gsheet
# 樂購DM05.gdoc
# 已經辨識過的.gsheet
# 廠商出貨流程.gdoc
# 電子報文檔 (1).gdoc
# 電子報文檔.gdoc
# PattaTech報價單_草莓網站.gdoc
# V017872_20091201對帳單明細表01.gsheet
# V017872_20091116對帳單明細表01.gsheet
# 長宏專案管理顧問公司 對帳單明細表 20091201.gsheet
# dotnetsleepless.gdoc
# 改善計畫.gdoc
# mANUAL capps密碼遺失帳號重新設定.gdoc
# manual taiwan data update check 為何有誤.gdoc
# manual 中國資料 ww 41 為何無法顯示.gdoc
# 美樂鍋具 對帳單明細表02 20091216.gsheet
# 打九折.gsheet
# 許芸嘉.gsheet
# mANUAL CITS系統agent代理商帳號新增or密碼變更.gdoc
# 產品名稱: 滷鴨翅膀.gdoc
# 郭宥忱.gsheet
# mANUAL pchome長宏對帳.gslides
# 長宏專案管理顧問公司 對帳單範本 (1).gsheet
# MANUAL討論區帳號資料.gdoc
# TODO.gdoc
# 外勞清潔事項.gdoc
# 產品名稱: 滷蛋.gdoc
# 商店街商品更新.gdoc
# 長宏專案管理顧問公司 對帳單20100415~20100430.gsheet
# 518人力銀行.gdoc
# 樂購花費.gdoc
# OWA密碼.gdoc
# 樂購會員名單.gdoc
# 樂購花費7月.gsheet
# 週末整潔查核表 .gdoc
# 長宏專案管理顧問公司 對帳單範本.gsheet
# 美樂鍋具 對帳單範本 v3.gsheet
# 遠傳 fareast 帳密 Mom.gdoc
# 遠傳帳密.gdoc
# binominal zero coupon pricing.gsheet
# Black Scholes.gsheet
# Cash and Carry Forward Price.gsheet
# cheapest to deliver.gsheet
# delta p modified duration decline_positive ExpectedLoss bayes binomial model Black-Scholes-Merton Spot rate Bond _VaR time.gsheet
# distribution uniform_standard_normal__Bernoulli_distribution Bionomial_Distiru Bionomial Poisson_ discrete.gsheet
# duration hedge delta p modified duration decline_positive ExpectedLoss bayes binomial model Black-Scholes-Merton Spot rate Bond _VaR time.gsheet

# %%
# Define the path to a specific folder in your Drive
project_folder_path = os.path.join(drive_path, 'my_project') # Creates '/content/drive/My Drive/my_project'

# Check if the project folder exists and list its contents
if os.path.exists(project_folder_path):
    print(f"\nItems in '{project_folder_path}':")
    for item in os.listdir(project_folder_path):
        print(item)

    # Define the path to a specific file
    data_file_path = os.path.join(project_folder_path, 'data.csv') # Creates '/content/drive/My Drive/my_project/data.csv'

    # Check if the data file exists
    if os.path.exists(data_file_path):
        print(f"\nData file found at: {data_file_path}")

        # Example: Reading a file from Drive (if it's a text file)
        try:
            with open(data_file_path, 'r') as f:
                first_line = f.readline()
                print(f"First line of {os.path.basename(data_file_path)}: {first_line.strip()}")
        except FileNotFoundError:
            print(f"Error: File not found at {data_file_path}")
        except Exception as e:
            print(f"An error occurred while reading the file: {e}")
    else:
        print(f"\nData file not found at: {data_file_path}")

else:
    print(f"\nProject folder not found at: {project_folder_path}")
# Out:
# Items in '/content/drive/My Drive/my_project':
# data.csv
#
# Data file found at: /content/drive/My Drive/my_project/data.csv
# First line of data.csv: Keyword,Frequency

# %%
import os

# Assuming drive_path is already defined, e.g.:
# drive_path = '/content/drive/My Drive/'

# Define the path to a specific folder in your Drive
project_folder_path = os.path.join(drive_path, 'my_project') # Creates '/content/drive/My Drive/my_project'

# Check if the project folder exists
if os.path.exists(project_folder_path):
    print(f"\nAccessing folder: '{project_folder_path}'")

    # Define the path to the specific file
    data_file_path = os.path.join(project_folder_path, 'data.csv') # Creates '/content/drive/My Drive/my_project/data.csv'

    # Check if the data file exists
    if os.path.exists(data_file_path):
        print(f"\nData file found at: {data_file_path}")

        # --- CHANGE STARTS HERE ---
        # Read and print the entire content of the file
        try:
            with open(data_file_path, 'r') as f:
                print(f"\n--- Content of {os.path.basename(data_file_path)} ---")
                file_content = f.read() # Read the entire file content
                print(file_content)      # Print the content
                print("--- End of file ---")

        except FileNotFoundError:
            print(f"Error: File not found at {data_file_path}")
        except Exception as e:
            print(f"An error occurred while reading the file: {e}")
        # --- CHANGE ENDS HERE ---

    else:
        print(f"\nData file not found at: {data_file_path}. Make sure 'data.csv' is in 'my_project'.")

else:
    print(f"\nProject folder not found at: {project_folder_path}. Make sure 'my_project' folder exists in your Drive.")
# Out:
# Accessing folder: '/content/drive/My Drive/my_project'
#
# Data file found at: /content/drive/My Drive/my_project/data.csv
#
# --- Content of data.csv ---
# Keyword,Frequency
# ABI (application binary interface),1
# deploying sample betting application,1
# fast-track application tutorial,1
# ...,1
# Zennet,1
# “zero-client” gateway,1
#
# --- End of file ---
